# %% [markdown]
# # *Import Packages and Libraries*

# %% [markdown]
# **Installing package "yfinance" using the pip command for fetching stock data of Companies/Index**

# %%
# !pip install yfinance

# %% [markdown]
# **Installing the "pandas datareader" package**

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Imported various Python libraries for working with data, financial data retrieval, visualization, and machine learning.**

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
from datetime import datetime
import yfinance as yf

# For time stamps
from datetime import datetime

import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from matplotlib.cbook import boxplot_stats

import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Out:
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # *Extracting Data from yfinance*

# %% [markdown]
# ### *Assigning Start and End date to variables for extracting data*

# %%
# Assign the date '01/04/2018' to the variable 'start' with datetime format
start = datetime.strptime('01/01/2020 00:00:00', '%d/%m/%Y %H:%M:%S')

# Display the value of 'start'
print(start)
# Out:
# 2020-01-01 00:00:00

# %%
# Assign the date '01/04/2023' to the variable 'end' with datetime format
end = datetime.strptime('01/03/2024 00:00:00', '%d/%m/%Y %H:%M:%S')

# Display the value of 'end'
print(end)
# Out:
# 2024-03-01 00:00:00

# %% [markdown]
# ## *Company: HCL Technologies Ltd.*
# ## *Industry: Information Technology Consulting Outsourcing*

# %%
hcltech = yf.download("HCLTECH.NS", start, end)
hcltech
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01   569.400024   572.900024   566.849976   571.950012   496.896912
# 2020-01-02   572.549988   575.000000   570.500000   573.549988   498.286957
# 2020-01-03   574.000000   588.500000   572.849976   585.049988   508.277924
# 2020-01-06   585.000000   592.200012   579.450012   582.000000   505.628143
# 2020-01-07   582.000000   587.750000   579.049988   584.250000   507.582794
# ...                 ...          ...          ...          ...          ...
# 2024-02-23  1697.000000  1697.349976  1663.449951  1665.750000  1665.750000
# 2024-02-26  1665.750000  1668.849976  1639.500000  1649.800049  1649.800049
# 2024-02-27  1649.000000  1673.400024  1648.000000  1658.800049  1658.800049
# 2024-02-28  1664.699951  1672.000000  1644.199951  1651.900024  1651.900024
# ...

# %%
# Exporting csv for reference
#hcltech.to_csv("hcltech_file.csv", index = True)

# %%
# Importing DataFrame
#hcltech = pd.read_csv('/kaggle/input/hcltech/hcltech_file.csv')

# Set the 'Date' column as the index
#hcltech.set_index('Date', inplace=True)

# Printing the DataFrame
#print(hcltech)

# %% [markdown]
# ## *Company: Sun Pharmaceutical Industries Ltd.*
# ## *Industry: Pharmaceutical*

# %%
sunpharma = yf.download("SUNPHARMA.NS", start, end)
sunpharma
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01   432.950012   436.450012   431.250000   434.299988   413.836670
# 2020-01-02   434.000000   442.600006   432.000000   434.950012   414.456024
# 2020-01-03   434.649994   450.399994   433.049988   444.600006   423.651367
# 2020-01-06   440.899994   444.700012   435.100006   439.950012   419.220459
# 2020-01-07   441.399994   448.000000   437.549988   446.399994   425.366486
# ...                 ...          ...          ...          ...          ...
# 2024-02-23  1558.000000  1568.449951  1550.400024  1561.250000  1561.250000
# 2024-02-26  1562.000000  1566.900024  1548.699951  1556.949951  1556.949951
# 2024-02-27  1556.750000  1585.449951  1549.050049  1582.750000  1582.750000
# 2024-02-28  1586.500000  1587.449951  1562.650024  1573.849976  1573.849976
# ...

# %%
# Exporting csv for reference
#sunpharma.to_csv("sunpharma_file.csv", index = True)

# %%
# Importing DataFrame
#sunpharma = pd.read_csv('/kaggle/input/sunpharma/sunpharma_file.csv')

# Set the 'Date' column as the index
#sunpharma.set_index('Date', inplace=True)

# Printing the DataFrame
#print(sunpharma)

# %% [markdown]
# ## *Company: HDFC Bank Ltd.*
# ## *Industry: Financial Services*

# %%
hdfcbank = yf.download("HDFCBANK.NS", start, end)
hdfcbank
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-01  1276.099976  1280.000000  1270.599976  1278.599976  1244.189697
# 2020-01-02  1279.000000  1288.000000  1279.000000  1286.750000  1252.120361
# 2020-01-03  1282.199951  1285.000000  1263.599976  1268.400024  1234.264160
# 2020-01-06  1260.000000  1261.800049  1236.000000  1240.949951  1207.552856
# 2020-01-07  1258.900024  1271.449951  1252.250000  1260.599976  1226.674072
# ...                 ...          ...          ...          ...          ...
# 2024-02-23  1422.550049  1433.900024  1418.000000  1420.599976  1420.599976
# 2024-02-26  1413.550049  1434.849976  1413.550049  1422.300049  1422.300049
# 2024-02-27  1413.550049  1426.699951  1413.050049  1420.150024  1420.150024
# 2024-02-28  1420.150024  1424.199951  1404.000000  1409.400024  1409.400024
# ...

# %%
# Exporting csv for reference
#hdfcbank.to_csv("hdfcbank_file.csv", index = True)

# %%
# Importing DataFrame
#hdfcbank = pd.read_csv('/kaggle/input/hdfcbank/hdfcbank_file.csv')

# Set the 'Date' column as the index
#hdfcbank.set_index('Date', inplace=True)

# Printing the DataFrame
#print(hdfcbank)

# %% [markdown]
# ## *Company: DLF Ltd.*
# ## *Industry: Real Estate Development*

# %%
dlf = yf.download("DLF.NS", start, end)
dlf
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-01  231.399994  232.149994  227.100006  227.550003  220.275879
# 2020-01-02  227.500000  234.399994  226.500000  233.750000  226.277679
# 2020-01-03  232.649994  233.699997  227.050003  228.600006  221.292313
# 2020-01-06  227.000000  227.550003  220.149994  220.949997  213.886856
# 2020-01-07  223.000000  227.449997  222.500000  225.500000  218.291382
# ...                ...         ...         ...         ...         ...
# 2024-02-23  898.000000  905.000000  892.349976  899.250000  899.250000
# 2024-02-26  898.000000  910.250000  887.700012  902.900024  902.900024
# 2024-02-27  905.000000  918.200012  902.900024  916.400024  916.400024
# 2024-02-28  914.200012  919.950012  893.599976  899.000000  899.000000
# 2024-02-29  898.000000  911.950012  881.650024  901.200012  901.200012
#
#               Volume
# Date
# ...

# %%
# Exporting csv for reference
#dlf.to_csv("dlf_file.csv", index = True)

# %%
# Importing DataFrame
#dlf = pd.read_csv('/kaggle/input/dlf-df/dlf_file.csv')

# Set the 'Date' column as the index
#dlf.set_index('Date', inplace=True)

# Printing the DataFrame
#print(dlf)

# %% [markdown]
# ## *Index: NIFTY50*

# %%
nifty50 = yf.download("^NSEI", start, end)
nifty50
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195
# ...                  ...           ...           ...           ...
# 2024-02-23  22290.000000  22297.500000  22186.099609  22212.699219
# 2024-02-26  22169.199219  22202.150391  22075.150391  22122.050781
# 2024-02-27  22090.199219  22218.250000  22085.650391  22198.349609
# 2024-02-28  22214.099609  22229.150391  21915.849609  21951.150391
# 2024-02-29  21935.199219  22060.550781  21860.650391  21982.800781
#
#                Adj Close  Volume
# Date
# 2020-01-01  12182.500000  304100
# ...

# %%
# Exporting csv for reference
#nifty50.to_csv("nifty50_file.csv", index = True)

# %%
# Importing DataFrame
#nifty50 = pd.read_csv('/kaggle/input/nifty50/nifty50_file.csv')

# Set the 'Date' column as the index
#nifty50.set_index('Date', inplace=True)

# Printing the DataFrame
#print(nifty50)

# %% [markdown]
# # *Creating the Dataset*

# %% [markdown]
# **Created the dataset of all above mentioned companies and index together**
#
# * HCL Tech
# * Sunpharma
# * HDFC Bank
# * DLF
# * Nifty50

# %%
# Converting all individual Company details dataset into DataFrames
hcltech = pd.DataFrame(hcltech)
sunpharma = pd.DataFrame(sunpharma)
hdfcbank = pd.DataFrame(hdfcbank)
dlf = pd.DataFrame(dlf)
nifty50 = pd.DataFrame(nifty50)

# %%
# Add a new column to each DataFrame to store the table names
hcltech['Company/Index Name'] = 'HCL Technologies Ltd.'
sunpharma['Company/Index Name'] = 'Sun Pharmaceutical Industries Ltd.'
hdfcbank['Company/Index Name'] = 'HDFC Bank Ltd.'
dlf['Company/Index Name'] = 'DLF Ltd.'
nifty50['Company/Index Name'] = 'NIFTY50'

# %%
# Concatenating the Datasets
df = pd.concat([hcltech, sunpharma, hdfcbank, dlf, nifty50])
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-01    569.400024    572.900024    566.849976    571.950012
# 2020-01-02    572.549988    575.000000    570.500000    573.549988
# 2020-01-03    574.000000    588.500000    572.849976    585.049988
# 2020-01-06    585.000000    592.200012    579.450012    582.000000
# 2020-01-07    582.000000    587.750000    579.049988    584.250000
# ...                  ...           ...           ...           ...
# 2024-02-23  22290.000000  22297.500000  22186.099609  22212.699219
# 2024-02-26  22169.199219  22202.150391  22075.150391  22122.050781
# 2024-02-27  22090.199219  22218.250000  22085.650391  22198.349609
# 2024-02-28  22214.099609  22229.150391  21915.849609  21951.150391
# 2024-02-29  21935.199219  22060.550781  21860.650391  21982.800781
#
#                Adj Close   Volume     Company/Index Name
# Date
# 2020-01-01    496.896912   918373  HCL Technologies Ltd.
# ...

# %%
# Exporting csv for reference
#df.to_csv("stock_analysis_df.csv", index = True)

# %% [markdown]
# # Check Data

# %% [markdown]
# **Viewing the top 5 records**

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-01  569.400024  572.900024  566.849976  571.950012  496.896912
# 2020-01-02  572.549988  575.000000  570.500000  573.549988  498.286957
# 2020-01-03  574.000000  588.500000  572.849976  585.049988  508.277924
# 2020-01-06  585.000000  592.200012  579.450012  582.000000  505.628143
# 2020-01-07  582.000000  587.750000  579.049988  584.250000  507.582794
#
#              Volume     Company/Index Name
# Date
# 2020-01-01   918373  HCL Technologies Ltd.
# 2020-01-02  1075642  HCL Technologies Ltd.
# 2020-01-03  3269446  HCL Technologies Ltd.
# 2020-01-06  3589985  HCL Technologies Ltd.
# 2020-01-07  3179728  HCL Technologies Ltd.

# %% [markdown]
# **Fetching the structure of the dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5169 entries, 2020-01-01 to 2024-02-29
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Open                5169 non-null   float64
#  1   High                5169 non-null   float64
#  2   Low                 5169 non-null   float64
#  3   Close               5169 non-null   float64
#  4   Adj Close           5169 non-null   float64
#  5   Volume              5169 non-null   int64
#  6   Company/Index Name  5169 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 323.1+ KB

# %% [markdown]
# # *Check Descriptive Analysis*

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   5169.000000   5169.000000   5169.000000   5169.000000   5169.000000
# mean    3933.206664   3957.025476   3903.401534   3930.946413   3907.945828
# std     6251.346461   6277.361139   6214.381944   6247.600065   6258.450077
# min      120.000000    127.400002    114.550003    120.800003    117.541534
# 25%      580.000000    588.500000    572.849976    579.150024    532.400024
# 50%     1070.949951   1081.900024   1056.500000   1071.250000   1027.009644
# 75%     1594.599976   1607.449951   1581.300049   1594.400024   1576.322876
# max    22290.000000  22297.500000  22186.099609  22217.449219  22217.449219
#
#              Volume
# count  5.169000e+03
# mean   6.080776e+06
# std    6.995110e+06
# min    0.000000e+00
# 25%    1.683827e+06
# 50%    4.078174e+06
# 75%    8.041379e+06
# max    8.670560e+07

# %% [markdown]
# **From the descriptive analysis, its inferred that the data is not normally distributed.**

# %% [markdown]
# # *Data Cleaning & Pre-processing*

# %% [markdown]
# ## *Missing Value Treatment*

# %%
df.isna().sum()
# Out:
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
# Volume                0
# Company/Index Name    0
# dtype: int64

# %% [markdown]
# ## Inference:
# **In this data, we are considering only the working days of the Stock Market hence the data doesn't include Holidays.**
#
# **Missing values not found for any other column**

# %% [markdown]
# ## *Normalising the data*

# %% [markdown]
# Usually, we do outlier treatment first and then normalization. But in case of Stock Market data etc, normalization is done before outlier treatment for the following reasons:
#
# * to preserve the data relationship - In stock market data, the relative movements and relationships between different stock prices and financial indicators are often more important than the absolute values.
# * applying outlier treatment on normalized data ensures that each feature is treated equally and consistently. Outliers can have a disproportionate impact on unscaled data, potentially leading to biased outlier detection and treatment. This becomes relevant if we are doing Principal Component Analysis.

# %% [markdown]
# **Creating function "normalize_dataset(df)" is designed to normalize the numerical columns of a given DataFrame using the Min-Max scaling technique**
#
# **Breakdown:**
# 1. Input Parameter:
# df: This is the DataFrame that you want to normalize.
# 2. Selecting Numerical Columns:
# The function first identifies the numerical columns within the DataFrame. It does this by using the select_dtypes method with the argument include=[float, int]. This filters and selects only the columns with data types of float and int, which are typically the data types for numerical values.
# 3. Normalization with Min-Max Scaler:
# It then initializes a Min-Max scaler object using scaler = MinMaxScaler(). The Min-Max scaler is a method used to transform numerical data into a specific range, often between 0 and 1.
# Next, it applies the Min-Max scaling transformation to the selected numerical columns using df[numerical_columns] = scaler.fit_transform(df[numerical_columns]). This step scales each numerical column independently, so that the minimum value in each column becomes 0, the maximum becomes 1, and all other values are scaled proportionally within this range.
# 4. Return the Normalized Dataset:
# Finally, the function returns the original DataFrame df, but with the numerical columns normalized.

# %%
def normalize_dataset(data):
    """
Normalize the numerical columns of a given DataFrame using the Min-Max scaling technique.

Parameters:
----------
data : pandas.DataFrame
    The DataFrame containing the data to be normalized.

Returns:
-------
pandas.DataFrame
    A new DataFrame with the same structure as the input 'data', but with the
    numerical columns scaled to the range [0, 1] using Min-Max scaling.

Usage:
------
# Example usage:
    normalized_data = normalize_dataset(df)
    """
    # Create a new DataFrame to store normalized values
    normalized_data = data.copy()
    
    # Select only numerical columns
    numerical_columns = normalized_data.select_dtypes(include=[float, int]).columns
    
    # Normalize numerical columns using Min-Max scaler
    scaler = MinMaxScaler()
    normalized_data[numerical_columns] = scaler.fit_transform(normalized_data[numerical_columns])
    
    # Return the normalized dataset
    return normalized_data

# Calling the Function
normalized_data = normalize_dataset(df)

# %%
normalized_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2020-01-01  0.020271  0.020095  0.020492  0.020417   0.017165  0.010592
# 2020-01-02  0.020413  0.020189  0.020658  0.020490   0.017228  0.012406
# 2020-01-03  0.020478  0.020798  0.020764  0.021010   0.017680  0.037707
# 2020-01-06  0.020974  0.020965  0.021063  0.020872   0.017561  0.041404
# 2020-01-07  0.020839  0.020764  0.021045  0.020974   0.017649  0.036673
#
#                Company/Index Name
# Date
# 2020-01-01  HCL Technologies Ltd.
# 2020-01-02  HCL Technologies Ltd.
# 2020-01-03  HCL Technologies Ltd.
# 2020-01-06  HCL Technologies Ltd.
# 2020-01-07  HCL Technologies Ltd.

# %% [markdown]
# **In summary, this function takes a DataFrame, identifies the numerical columns, scales the values within those columns to a specified range (typically 0 to 1), and returns the DataFrame with the normalized numerical values. This is useful for ensuring that numerical features are on a similar scale, which can be important for certain machine learning algorithms and data analysis techniques.**

# %% [markdown]
# ## *Outlier Treatment*

# %% [markdown]
# **This function named mark_outliers_zscore is intended for identifying outliers in a dataset based on the z-score method.**
#
# **Breakdown:**
# 1. Input Parameters:
# * data: This parameter represents the dataset or DataFrame in which you want to identify outliers.
# * column_name: It specifies the name of the column within the dataset where you want to detect outliers.
# * threshold: This is an optional parameter with a default value of 3.0. It determines the threshold beyond which data points are considered outliers based on their z-scores.
# 2. Calculating Z-Scores:
# The function calculates the z-scores for the specified column. Z-scores measure how many standard deviations a data point is away from the mean of the column. The formula used is: (x - mean) / standard deviation, where x is each data point in the specified column.
# 3. Creating an 'Outlier' Column:
# It creates a new column named 'Outlier' in the input dataset data.
# 4. Identifying Outliers:
# For each data point in the specified column, it compares the absolute value of its z-score to the provided threshold. If the absolute z-score is greater than the threshold, it is considered an outlier. Otherwise, it's not considered an outlier.
# 5. Printing Unique Outlier Values:
# The function then prints the unique values found in the 'Outlier' column. This will typically show True for data points that are outliers according to the specified threshold and False for non-outliers.

# %%
# Create a function to identify Outliers
def mark_outliers_zscore(data, column_name, threshold=3.0):
    """
Detects and treats outliers in data using z score.

Parameters:
-----------
    data: A list or NumPy array of data.
    cutoff: The cutoff value for z scores. Any data point with a z score greater than
    cutoff or less than -cutoff is considered an outlier.
    
Returns:
--------
    A list or NumPy array of the data with outliers removed.
    
Usage:
------
    df_open = mark_outliers_zscore(normalized_data, 'Open')
    """
    # Create a new DataFrame to store normalized values
    outlier_data = data.copy()
    
    # Calculate the z-scores for the specified column
    z_scores = (outlier_data[column_name] - outlier_data[column_name].mean()) / outlier_data[column_name].std()

    # Create a new 'Outlier' column based on the z-scores
    outlier_data['Outlier'] = abs(z_scores) > threshold

    # Return the outlier dataset
    return outlier_data

# %% [markdown]
# **In summary, this function calculates z-scores for a given column in the dataset and marks data points as outliers if their z-scores exceed a certain threshold. The result is a new column in the dataset ('Outlier') that indicates whether each data point in the specified column is an outlier or not, and it prints the unique values in this 'Outlier' column, which will typically be True or False.**

# %%
# Call the function to mark outliers using z-score for the 'Open' column
stock_analysis_df_open = mark_outliers_zscore(normalized_data, 'Open')
stock_analysis_df_open['Outlier'].unique()
# Out:
# array([False])

# %% [markdown]
# **The output 'False' indicates that there are no outliers present in the 'Open' column**

# %%
# Call the function to mark outliers using z-score for the 'High' column
stock_analysis_df_high = mark_outliers_zscore(normalized_data, 'High')
stock_analysis_df_high['Outlier'].unique()
# Out:
# array([False])

# %% [markdown]
# **The output 'False' indicates that there are no outliers present in the 'High' column**

# %%
# Call the function to mark outliers using z-score for the 'Low' column
stock_analysis_df_low = mark_outliers_zscore(normalized_data, 'Low')
stock_analysis_df_low['Outlier'].unique()
# Out:
# array([False])

# %% [markdown]
# **The output 'False' indicates that there are no outliers present in the 'Low' column**

# %%
# Call the function to mark outliers using z-score for the 'Close' column
stock_analysis_df_close = mark_outliers_zscore(normalized_data, 'Close')
stock_analysis_df_close['Outlier'].unique()
# Out:
# array([False])

# %% [markdown]
# **The output 'False' indicates that there are no outliers present in the 'Close' column**

# %%
# Call the function to mark outliers using z-score for the 'Adj Close' column
stock_analysis_df_adjclose = mark_outliers_zscore(normalized_data, 'Adj Close')
stock_analysis_df_adjclose['Outlier'].unique()
# Out:
# array([False])

# %% [markdown]
# **The output 'False' indicates that there are no outliers present in the 'Adj Close' column**

# %%
# Call the function to mark outliers using z-score for the 'Volume' column
stock_analysis_df_volume = mark_outliers_zscore(normalized_data, 'Volume')
stock_analysis_df_volume['Outlier'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# **The output indicates that there are outliers present in the 'Volume' column**

# %% [markdown]
# **Fetching the records with 'Outlier' = 'True'**

# %%
# Print rows where the 'Outlier' column is True
outliers_true = stock_analysis_df_volume[stock_analysis_df_volume['Outlier'] == True]
print(outliers_true)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2020-09-14  0.028191  0.031470  0.028525  0.030509   0.026221  0.372669
# 2020-10-16  0.033333  0.033811  0.031989  0.031966   0.027498  0.334269
# 2020-04-03  0.010101  0.011836  0.010215  0.011547   0.011008  0.329280
# 2020-04-07  0.012539  0.013327  0.012403  0.013421   0.012806  0.342251
# 2020-04-08  0.013487  0.014495  0.013529  0.014296   0.013646  0.320751
# ...              ...       ...       ...       ...        ...       ...
# 2021-09-22  0.009601  0.011112  0.009809  0.011235   0.011120  0.490464
# 2021-09-23  0.011376  0.012873  0.011574  0.012719   0.012581  0.881858
# 2021-09-24  0.012828  0.013121  0.012829  0.013108   0.012965  0.505109
# 2021-09-27  0.013268  0.013554  0.013468  0.013541   0.013390  0.375757
# 2023-05-15  0.014569  0.015715  0.014757  0.015720   0.015699  0.324278
#
#                             Company/Index Name  Outlier
# Date
# ...

# %% [markdown]
# **Fetching the company names with outliers present**

# %%
outliers_true['Company/Index Name'].unique()
# Out:
# array(['HCL Technologies Ltd.', 'Sun Pharmaceutical Industries Ltd.',
#        'HDFC Bank Ltd.', 'DLF Ltd.'], dtype=object)

# %% [markdown]
# ### Inference:
# **As the data points in this dataset are actual values of stocks fetched from yfinance, we will not be treating the outlier values occuring in the 'Volume' column.**
#
# **Would outlier treatment be of any significance in case of stock market data?**
#
# * Outlier identification and treatment can be of significant importance when working with stock market data, but the approach to handling outliers in this context can be complex.
# * Outliers in stock market data might represent errors, glitches, or data inaccuracies.It could be indicative of significant events, such as earnings releases, news announcements, market crashes, or other market-moving events. Identifying and understanding these outliers can provide valuable insights into market dynamics and investor behaviour.

# %% [markdown]
# # 1. *What was the change in price of the stock overtime?*

# %% [markdown]
# ## *Adjusted Closing Price*

# %% [markdown]
# **The Adjusted Closing Price amends a stock's closing price to reflect that stock's value after accounting for any corporate actions. It is often used when examining historical returns or doing a detailed analysis of past performance.**

# %%
tech_list = ['hcltech', 'sunpharma', 'hdfcbank', 'dlf', 'nifty50']
company_list = [hcltech, sunpharma, hdfcbank, dlf, nifty50]
company_name = ['hcltech', 'sunpharma', 'hdfcbank', 'dlf', 'nifty50']

# %%
# Let's see a historical view of the adjusted closing price
plt.figure(figsize=(15, 25))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(5, 1, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Adjusted Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %% [markdown]
# **Observation : Adjusted closing price of all companies has shown downward trend during the time of COVID-19 Pandemic.**
#
# **- HCL TECH : There was normal upside movement uptill 2020 but after COVID downfall share price got doubled within a year having 800 as multiple resistance and support level.**
#
# **- Sunpharma : Due to FDA license disapproval stock price was down by 35% in the last quarter of 2018, it did not perform well after that as well and slumped down more in the beginning of COVID, but due to boom in Pharmaceutical industry during pandemic, the share recovered its ATH price in 2021 beginning and has grown continously afer that.**
#
# **- HDFC Bank : Share was performing very well before COVID, during pandemic it went down to 750 but recovered fast within 6 months and touched level of 1500 within a year and is prevailing in 1500-1600 since then.**
#
# **- DLF : It was showing a sign of good growth before COVID but pandemic proved to be a bane in its story. It took almost a year for the stock to recover but after that it has shown an exponential growth.**
#
# **- NIFTY 50 : Index being a result a top 50 companies was growing continously but COVID hit hard and resulted in a fall of 40%, this shows average decline in values of top performing companies but the recovery was quick and it has reached to ATH levels growing continously.**

# %% [markdown]
# ### *Calculating the Year-on-Year change in the Adjusted Closing Price of each Company/Index*

# %%
import datetime

# List of years
years = [2018, 2019, 2020, 2021, 2022, 2023]

# Check the day of the week for March 31st in each year
for year in years:
    date = datetime.date(year, 3, 31)
    day_of_week = date.strftime('%A')  # Get the full day name
    print(f"March 31, {year} falls on a {day_of_week}.")
# Out:
# March 31, 2018 falls on a Saturday.
# March 31, 2019 falls on a Sunday.
# March 31, 2020 falls on a Tuesday.
# March 31, 2021 falls on a Wednesday.
# March 31, 2022 falls on a Thursday.
# March 31, 2023 falls on a Friday.

# %% [markdown]
# ### ***Fetching data (including year 2018 closing) for year-on-year calculation***

# %%
from datetime import datetime

# %%
start18 = datetime.strptime('28/03/2018', '%d/%m/%Y')
# Display the value of 'start'
print(start18)
# Out:
# 2018-03-28 00:00:00

# %%
end18 = datetime.strptime('01/04/2023', '%d/%m/%Y')
# Display the value of 'start'
print(end18)
# Out:
# 2023-04-01 00:00:00

# %%
hcltech_2018 = yf.download("HCLTECH.NS", start18, end18)
hcltech_2018
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-03-28   480.774994   490.799988   477.524994   484.299988   415.041687
# 2018-04-02   483.149994   492.450012   482.399994   489.750000   419.712311
# 2018-04-03   486.250000   494.500000   481.524994   484.625000   415.320312
# 2018-04-04   490.500000   490.625000   474.750000   479.625000   411.035309
# 2018-04-05   485.000000   492.100006   478.274994   481.024994   412.235168
# ...                 ...          ...          ...          ...          ...
# 2023-03-24  1073.000000  1090.000000  1047.050049  1051.750000  1007.750549
# 2023-03-27  1053.300049  1065.500000  1044.800049  1051.500000  1007.511108
# 2023-03-28  1056.800049  1063.800049  1039.349976  1041.099976   997.546082
# 2023-03-29  1046.000000  1070.000000  1042.099976  1067.500000  1022.841675
# ...

# %%
sunpharma_2018 = yf.download("SUNPHARMA.NS", start18, end18)
sunpharma_2018
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-28  504.000000  504.700012  492.000000  495.100006  467.317169
# 2018-04-02  500.899994  510.000000  496.049988  507.850006  479.351685
# 2018-04-03  506.000000  512.200012  504.500000  510.000000  481.381073
# 2018-04-04  514.950012  514.950012  501.000000  502.250000  474.066010
# 2018-04-05  506.000000  513.000000  505.100006  507.549988  479.068542
# ...                ...         ...         ...         ...         ...
# 2023-03-24  977.599976  979.000000  968.000000  972.849976  963.926514
# 2023-03-27  980.000000  990.950012  963.000000  983.450012  974.429260
# 2023-03-28  987.000000  987.799988  976.299988  984.200012  975.172363
# 2023-03-29  985.650024  996.500000  979.000000  991.900024  982.801819
# 2023-03-31  995.200012  995.200012  981.400024  983.099976  974.082458
#
#              Volume
# Date
# ...

# %%
hdfcbank_2018 = yf.download("HDFCBANK.NS", start18, end18)
hdfcbank_2018
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-03-28   941.474976   949.849976   938.025024   943.049988   904.201233
# 2018-04-02   945.250000   967.875000   945.250000   965.599976   925.822327
# 2018-04-03   961.974976   962.849976   955.500000   957.950012   918.487488
# 2018-04-04   956.474976   962.474976   939.224976   941.625000   902.835083
# 2018-04-05   950.650024   957.000000   945.099976   954.450012   915.131714
# ...                 ...          ...          ...          ...          ...
# 2023-03-24  1560.000000  1573.900024  1554.949951  1560.650024  1542.955566
# 2023-03-27  1562.199951  1579.449951  1558.900024  1567.449951  1549.678345
# 2023-03-28  1565.699951  1582.900024  1564.099976  1580.199951  1562.283813
# 2023-03-29  1584.000000  1602.000000  1581.900024  1587.800049  1569.797729
# ...

# %%
dlf_2018 = yf.download("DLF.NS", start18, end18)
dlf_2018
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-03-28  205.699997  207.899994  200.449997  201.250000  191.877686
# 2018-04-02  203.699997  204.000000  197.600006  201.000000  191.639343
# 2018-04-03  200.000000  205.250000  199.000000  203.300003  193.832245
# 2018-04-04  204.600006  208.100006  197.750000  198.600006  189.351120
# 2018-04-05  202.899994  206.850006  202.000000  206.250000  196.644836
# ...                ...         ...         ...         ...         ...
# 2023-03-24  366.000000  368.000000  353.049988  354.250000  351.475922
# 2023-03-27  355.200012  357.450012  347.450012  348.799988  346.068573
# 2023-03-28  350.549988  353.200012  347.250000  348.649994  345.919769
# 2023-03-29  349.200012  354.000000  346.500000  352.549988  349.789215
# 2023-03-31  354.350006  360.750000  354.200012  356.700012  353.906738
#
#              Volume
# Date
# ...

# %%
nifty50_2018 = yf.download("^NSEI", start18, end18)
nifty50_2018
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2018-03-28  10143.599609  10158.349609  10096.900391  10113.700195
# 2018-04-02  10151.650391  10220.099609  10127.750000  10211.799805
# 2018-04-03  10186.849609  10255.349609  10171.049805  10245.000000
# 2018-04-04  10274.599609  10279.849609  10111.299805  10128.400391
# 2018-04-05  10228.450195  10331.799805  10227.450195  10325.150391
# ...                  ...           ...           ...           ...
# 2023-03-24  17076.199219  17109.449219  16917.349609  16945.050781
# 2023-03-27  16984.300781  17091.000000  16918.550781  16985.699219
# 2023-03-28  17031.750000  17061.750000  16913.750000  16951.699219
# 2023-03-29  16977.300781  17126.150391  16940.599609  17080.699219
# 2023-03-31  17210.349609  17381.599609  17204.650391  17359.750000
#
#                Adj Close  Volume
# Date
# 2018-03-28  10113.700195  344400
# ...

# %%
# Add a new column to each DataFrame to store the table names
hcltech_2018['Company/Index Name'] = 'HCL Technologies Ltd.'
sunpharma_2018['Company/Index Name'] = 'Sun Pharmaceutical Industries Ltd.'
hdfcbank_2018['Company/Index Name'] = 'HDFC Bank Ltd.'
dlf_2018['Company/Index Name'] = 'DLF Ltd.'
nifty50_2018['Company/Index Name'] = 'NIFTY50'

# %%
# Reset index and create a new column for dates
hcltech_reset = hcltech_2018.reset_index()
#hcltech_reset['DateColumn'] = hcltech_reset['Date']

sunpharma_reset = sunpharma_2018.reset_index()
#sunpharma_reset['DateColumn'] = sunpharma_reset['Date']

hdfcbank_reset = hdfcbank_2018.reset_index()
#hdfcbank_reset['DateColumn'] = hdfcbank_reset['Date']

dlf_reset = dlf_2018.reset_index()
#dlf_reset['DateColumn'] = dlf_reset['Date']

nifty50_reset = nifty50_2018.reset_index()
#nifty50_reset['DateColumn'] = nifty50_reset['Date']

# %%
# Concatenating all individual company datasets into one DataFrame
df_yoy = pd.concat([hcltech_reset, sunpharma_reset, hdfcbank_reset, dlf_reset, nifty50_reset])
df_yoy
# Out:
#            Date          Open          High           Low         Close  \
# 0    2018-03-28    480.774994    490.799988    477.524994    484.299988
# 1    2018-04-02    483.149994    492.450012    482.399994    489.750000
# 2    2018-04-03    486.250000    494.500000    481.524994    484.625000
# 3    2018-04-04    490.500000    490.625000    474.750000    479.625000
# 4    2018-04-05    485.000000    492.100006    478.274994    481.024994
# ...         ...           ...           ...           ...           ...
# 1231 2023-03-24  17076.199219  17109.449219  16917.349609  16945.050781
# 1232 2023-03-27  16984.300781  17091.000000  16918.550781  16985.699219
# 1233 2023-03-28  17031.750000  17061.750000  16913.750000  16951.699219
# 1234 2023-03-29  16977.300781  17126.150391  16940.599609  17080.699219
# 1235 2023-03-31  17210.349609  17381.599609  17204.650391  17359.750000
#
#          Adj Close   Volume     Company/Index Name
# 0       415.041687  4620172  HCL Technologies Ltd.
# ...

# %%
# Year end dates (based on the last working days)
dates_to_filter = ["2018-03-28", "2019-03-28", "2020-03-31", "2021-03-31", "2022-03-31", "2023-03-31"]

# Fetching the records for the year end dates
f_rows = df_yoy[df_yoy['Date'].isin(dates_to_filter)]
print(f_rows)
# Out:
#            Date          Open          High           Low         Close  \
# 0    2018-03-28    480.774994    490.799988    477.524994    484.299988
# 246  2019-03-28    525.700012    544.174988    525.000000    541.450012
# 492  2020-03-31    433.200012    449.399994    425.299988    436.399994
# 741  2021-03-31   1000.000000   1000.000000    978.650024    982.650024
# 989  2022-03-31   1174.800049   1174.800049   1161.000000   1163.750000
# 1238 2023-03-31   1083.400024   1096.900024   1069.400024   1085.250000
# 0    2018-03-28    504.000000    504.700012    492.000000    495.100006
# 246  2019-03-28    465.000000    479.799988    465.000000    475.450012
# 492  2020-03-31    340.100006    355.000000    328.250000    352.299988
# 741  2021-03-31    598.200012    606.000000    595.700012    597.799988
# 989  2022-03-31    920.599976    927.000000    910.799988    914.750000
# 1238 2023-03-31    995.200012    995.200012    981.400024    983.099976
# ...

# %%
# Changing column names
date_yoy = f_rows['Date']
company_yoy = f_rows['Company/Index Name']
adjclose_yoy = f_rows['Adj Close']

# %%
# Creating dataframe with only relevant columns for ease of analysis
pd_yoy = pd.DataFrame({'Date': date_yoy, 'Company': company_yoy,'Adj Close': adjclose_yoy})
pd_yoy
# Out:
#            Date                             Company     Adj Close
# 0    2018-03-28               HCL Technologies Ltd.    415.041687
# 246  2019-03-28               HCL Technologies Ltd.    467.825104
# 492  2020-03-31               HCL Technologies Ltd.    380.404449
# 741  2021-03-31               HCL Technologies Ltd.    869.048462
# 989  2022-03-31               HCL Technologies Ltd.   1064.187378
# 1238 2023-03-31               HCL Technologies Ltd.   1039.849121
# 0    2018-03-28  Sun Pharmaceutical Industries Ltd.    467.317169
# 246  2019-03-28  Sun Pharmaceutical Industries Ltd.    450.123108
# 492  2020-03-31  Sun Pharmaceutical Industries Ltd.    338.123871
# 741  2021-03-31  Sun Pharmaceutical Industries Ltd.    579.863281
# 989  2022-03-31  Sun Pharmaceutical Industries Ltd.    896.661072
# 1238 2023-03-31  Sun Pharmaceutical Industries Ltd.    974.082458
# 0    2018-03-28                      HDFC Bank Ltd.    904.201233
# ...

# %%
#!pip install tabulate
#from tabulate import tabulate

# %%
# Extract the year from the 'Date' column and create a new 'Year' column
pd_yoy['Date'] = pd.to_datetime(pd_yoy['Date'])
pd_yoy['Year'] = pd_yoy['Date'].dt.year

# Sort the DataFrame by 'Company', 'Year', and 'Date'
pd_yoy.sort_values(by=['Year', 'Date'], inplace=True) #'Company', 

# Calculate the year-on-year change for the 'Adj Close' column
pd_yoy['Yearly Change'] = (pd_yoy.groupby('Company')['Adj Close'].pct_change() * 100).round(2)

# Sort the DataFrame by 'Company' and 'Date'
pd_yoy.sort_values(by=['Company', 'Date'], inplace=True)

# Create a pivot table
pivot_table = pd_yoy.pivot(index='Company', columns='Year', values='Yearly Change')
formatted_yoy_df = pivot_table.applymap(lambda x: f'{x:.2f}%')
formatted_yoy_df = formatted_yoy_df.drop(columns = 2018)

print(formatted_yoy_df)
# Out:
# Year                                  2019     2020     2021    2022    2023
# Company
# DLF Ltd.                            -3.19%  -28.00%  109.92%  33.40%  -5.50%
# HCL Technologies Ltd.               12.72%  -18.69%  128.45%  22.45%  -2.29%
# HDFC Bank Ltd.                      22.87%  -24.51%   73.30%  -1.13%  10.74%
# NIFTY50                             14.40%  -25.69%   70.87%  18.88%  -0.60%
# Sun Pharmaceutical Industries Ltd.  -3.68%  -24.88%   71.49%  54.63%   8.63%

# %% [markdown]
# **Inference:**
#
# **During the period 2019 to 2020 (2019-2020):**
# DLF Ltd, Sun Pharmaceutical Industries Ltd, HCL Technologies Ltd. and HDFC Bank
# Ltd. experienced significant decreases in their adjusted closing prices
#
# The NIFTY50 index, which represents the broader market, had a negative return of -
# 25.69% during this period, indicating a general market downturn.
#
#
# **During the period 2020 to 2021 (2020-2021):**
# In 2021, there was a significant recovery in stock prices.
# DLF Ltd, Sun Pharmaceutical Industries Ltd, HCL Technologies Ltd. and HDFC Bank
# showed strong positive returns
#
# The NIFTY50 index rebounded with a positive return of 70.87%, reflecting a broader
# market recovery.
#
#
# **During the period 2021 to 2022 (2021-2022):**
# Most of the stocks continued to perform well in 2022.
#
# * DLF Ltd. and Sun Pharmaceutical Industries Ltd. showed positive returns of 33.40% and 54.63%, respectively.
# * HCL Technologies Ltd. and HDFC Bank Ltd. also had positive returns, although more modest, with HCL Technologies Ltd. gaining 22.45% and HDFC Bank Ltd. gaining 1.13%.
# * The NIFTY50 index had a positive return of 18.88%, indicating overall market growth.
#
#
# **During the period 2022 to 2023 (2022-2023):**
# In 2023, most stocks experienced a mixed performance.
# * DLF Ltd. had a negative return of -5.50%, indicating a decline in its adjusted closing price.
# * HCL Technologies Ltd. and HDFC Bank Ltd. also saw minor negative returns
# * Sun Pharmaceutical Industries Ltd. continued to perform well with a positive
# * return of 8.63%.
# * The NIFTY50 index had a slight decline with a negative return of -0.60%

# %% [markdown]
# # *2. What was the weekly return of the stock on average?*

# %% [markdown]
# ### *Converting Index to DateTimeIndex*

# %%
# Convert the index to a DatetimeIndex
df.index = pd.to_datetime(df.index)

# %%
# Convert the index to a DatetimeIndex
hcltech.index = pd.to_datetime(hcltech.index)

# %%
# Convert the index to a DatetimeIndex
sunpharma.index = pd.to_datetime(sunpharma.index)

# %%
# Convert the index to a DatetimeIndex
hdfcbank.index = pd.to_datetime(hdfcbank.index)

# %%
# Convert the index to a DatetimeIndex
dlf.index = pd.to_datetime(dlf.index)

# %%
# Convert the index to a DatetimeIndex
nifty50.index = pd.to_datetime(nifty50.index)

# %% [markdown]
# ### *Filtering data for every Thursday (stock market end of week)*

# %%
df_thurs = df[df.index.weekday == 3]
df_thurs
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-02    572.549988    575.000000    570.500000    573.549988
# 2020-01-09    586.000000    588.150024    579.250000    580.299988
# 2020-01-16    597.000000    598.299988    586.750000    593.250000
# 2020-01-23    590.099976    599.950012    587.000000    598.950012
# 2020-01-30    612.000000    613.849976    603.650024    607.849976
# ...                  ...           ...           ...           ...
# 2024-02-01  21780.650391  21832.949219  21658.750000  21697.449219
# 2024-02-08  22009.650391  22011.050781  21665.300781  21717.949219
# 2024-02-15  21906.550781  21953.849609  21794.800781  21910.750000
# 2024-02-22  22081.550781  22252.500000  21875.250000  22217.449219
# 2024-02-29  21935.199219  22060.550781  21860.650391  21982.800781
#
#                Adj Close   Volume     Company/Index Name
# Date
# 2020-01-02    498.286957  1075642  HCL Technologies Ltd.
# ...

# %%
hcltech_thurs = hcltech[hcltech.index.weekday == 3]
hcltech_thurs
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02   572.549988   575.000000   570.500000   573.549988   498.286957
# 2020-01-09   586.000000   588.150024   579.250000   580.299988   504.151154
# 2020-01-16   597.000000   598.299988   586.750000   593.250000   515.401855
# 2020-01-23   590.099976   599.950012   587.000000   598.950012   520.353943
# 2020-01-30   612.000000   613.849976   603.650024   607.849976   529.855347
# ...                 ...          ...          ...          ...          ...
# 2024-02-01  1576.000000  1597.000000  1566.349976  1577.400024  1577.400024
# 2024-02-08  1626.000000  1647.699951  1617.300049  1633.800049  1633.800049
# 2024-02-15  1678.000000  1696.500000  1650.099976  1662.550049  1662.550049
# 2024-02-22  1644.000000  1691.400024  1639.000000  1686.400024  1686.400024
# 2024-02-29  1642.150024  1677.750000  1636.650024  1663.849976  1663.849976
#
#              Volume     Company/Index Name
# Date
# ...

# %%
sunpharma_thurs = sunpharma[sunpharma.index.weekday == 3]
sunpharma_thurs
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02   434.000000   442.600006   432.000000   434.950012   414.456024
# 2020-01-09   442.700012   444.850006   439.000000   439.850006   419.125122
# 2020-01-16   452.250000   456.350006   447.399994   449.049988   427.891602
# 2020-01-23   447.200012   452.200012   445.000000   449.850006   428.653931
# 2020-01-30   451.500000   453.750000   440.299988   442.100006   421.269135
# ...                 ...          ...          ...          ...          ...
# 2024-02-01  1427.000000  1430.449951  1398.900024  1407.949951  1399.969482
# 2024-02-08  1501.050049  1507.500000  1485.349976  1499.599976  1491.099976
# 2024-02-15  1529.050049  1529.050049  1505.550049  1509.900024  1509.900024
# 2024-02-22  1549.599976  1561.000000  1535.000000  1558.050049  1558.050049
# 2024-02-29  1575.000000  1587.800049  1556.500000  1577.949951  1577.949951
#
# ...

# %%
hdfcbank_thurs = hdfcbank[hdfcbank.index.weekday == 3]
hdfcbank_thurs
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  1279.000000  1288.000000  1279.000000  1286.750000  1252.120361
# 2020-01-09  1265.000000  1275.800049  1263.099976  1271.400024  1237.183594
# 2020-01-16  1282.050049  1291.000000  1279.349976  1287.650024  1252.996216
# 2020-01-23  1240.000000  1246.849976  1231.000000  1244.849976  1211.348022
# 2020-01-30  1238.949951  1238.949951  1217.199951  1226.050049  1193.053955
# ...                 ...          ...          ...          ...          ...
# 2024-02-01  1465.050049  1473.599976  1456.050049  1466.349976  1466.349976
# 2024-02-08  1429.849976  1438.949951  1400.500000  1403.050049  1403.050049
# 2024-02-15  1385.000000  1415.500000  1384.349976  1414.050049  1414.050049
# 2024-02-22  1417.750000  1428.800049  1412.199951  1419.550049  1419.550049
# 2024-02-29  1402.099976  1410.400024  1397.300049  1403.400024  1403.400024
#
#               Volume Company/Index Name
# Date
# ...

# %%
dlf_thurs = dlf[dlf.index.weekday == 3]
dlf_thurs
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  227.500000  234.399994  226.500000  233.750000  226.277679
# 2020-01-09  230.000000  240.500000  229.350006  238.250000  230.633804
# 2020-01-16  255.699997  259.649994  254.649994  258.149994  249.897644
# 2020-01-23  258.100006  262.000000  257.100006  260.700012  252.366165
# 2020-01-30  258.600006  258.850006  252.050003  254.649994  246.509552
# ...                ...         ...         ...         ...         ...
# 2024-02-01  802.549988  808.750000  791.049988  800.049988  800.049988
# 2024-02-08  828.799988  840.900024  823.150024  830.849976  830.849976
# 2024-02-15  848.000000  857.950012  842.500000  851.400024  851.400024
# 2024-02-22  894.000000  895.000000  878.849976  892.250000  892.250000
# 2024-02-29  898.000000  911.950012  881.650024  901.200012  901.200012
#
#               Volume Company/Index Name
# Date
# 2020-01-02   4513308           DLF Ltd.
# ...

# %%
nifty50_thurs = nifty50[nifty50.index.weekday == 3]
nifty50_thurs
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195
# 2020-01-09  12153.150391  12224.049805  12132.549805  12215.900391
# 2020-01-16  12347.099609  12389.049805  12315.799805  12355.500000
# 2020-01-23  12123.750000  12189.000000  12094.099609  12180.349609
# 2020-01-30  12147.750000  12150.299805  12010.599609  12035.799805
# ...                  ...           ...           ...           ...
# 2024-02-01  21780.650391  21832.949219  21658.750000  21697.449219
# 2024-02-08  22009.650391  22011.050781  21665.300781  21717.949219
# 2024-02-15  21906.550781  21953.849609  21794.800781  21910.750000
# 2024-02-22  22081.550781  22252.500000  21875.250000  22217.449219
# 2024-02-29  21935.199219  22060.550781  21860.650391  21982.800781
#
#                Adj Close  Volume Company/Index Name
# Date
# 2020-01-02  12282.200195  407700            NIFTY50
# ...

# %% [markdown]
# **The below code is intended to calculate the weekly returns for each company in a list of DataFrames called company_list_week.** **Breakdown:**
# 1. Loop Over company_list_week:
# The code starts a loop that iterates over each DataFrame in the company_list_week. Each DataFrame presumably contains financial data for a specific company.
# 2. Calculating Weekly Returns:
# * within the loop, for each company, it calculates the weekly returns and stores them in a new column named 'Weekly Return' within that company's DataFrame.
# * company['Adj Close'] accesses the 'Adj Close' column of the DataFrame. This column is typically used to represent the adjusted closing price of a company's stock.
# * .pct_change() is a pandas function that calculates the percentage change between each element and the previous element in a Series (or DataFrame column). This operation effectively computes the weekly returns as the percentage change in the 'Adj Close' prices.
#
# **So, after this loop completes, each DataFrame in company_list_week will have a new column named 'Weekly Return', which contains the weekly returns calculated as the percentage change in the 'Adj Close' prices. These returns represent the weekly investment performance of each company's stock.**

# %%
company_list_week = [hcltech_thurs,sunpharma_thurs,hdfcbank_thurs,dlf_thurs,nifty50_thurs]

# We'll use pct_change to find the percent change for each week
for company in company_list_week:
    company['Weekly Return'] = company['Adj Close'].pct_change()

# Then we'll plot the daily return percentage
fig, axes = plt.subplots(nrows=5, ncols=1)
fig.set_figheight(25)
fig.set_figwidth(15)

hcltech_thurs['Weekly Return'].plot(ax=axes[0], legend=True, linestyle='--', marker='o')
axes[0].set_title('hcltech')

sunpharma_thurs['Weekly Return'].plot(ax=axes[1], legend=True, linestyle='--', marker='o')
axes[1].set_title('sunpharma')

hdfcbank_thurs['Weekly Return'].plot(ax=axes[2], legend=True, linestyle='--', marker='o')
axes[2].set_title('hdfcbank')

dlf_thurs['Weekly Return'].plot(ax=axes[3], legend=True, linestyle='--', marker='o')
axes[3].set_title('dlf')

nifty50_thurs['Weekly Return'].plot(ax=axes[4], legend=True, linestyle='--', marker='o')
axes[4].set_title('nifty50')

fig.tight_layout()
# Out:
# C:\Users\prave\AppData\Local\Temp\ipykernel_17800\2702423956.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company['Weekly Return'] = company['Adj Close'].pct_change()
# C:\Users\prave\AppData\Local\Temp\ipykernel_17800\2702423956.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company['Weekly Return'] = company['Adj Close'].pct_change()
# C:\Users\prave\AppData\Local\Temp\ipykernel_17800\2702423956.py:5: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Observations:
# **These charts show us the distribution of weekly returns of these stocks:**
#
# 1. HCLTECH: The weekly data is mostly scattered in the range of -5% to 5%. Being a less volatile share, HCLTECH doesn't have any major weekly.
# 2. Sunpharma: This share is more volatile than HCLTECH as the data is mostly scattered in the range of -10% to 10% except for the Pandemic period. Being a Pharmaceutical company, it has shown good returns in the COVID-19 period.
# 3. HDFCBank: The weekly data is mostly scattered in the range of -5% to 5%. In 2019, the company declared a 30% growth in Y-O-Y Net Profit for F.Y. 2018, which lead to the sudden spike. Similarly, in the year 2021, the company reported 18% growth in Y-O-Y Net Profit for Q4 2020.
# 4. DLF: This share is more volatile as the data is mostly scattered in the range of -15% to 15%.
# 5. NIFTY50: Being an index of 50 different shares the return of NIFTY is balanced, making it less volatile.
#
# **All the above have shown diversions from their behaviour During the COVID-19 Pandemic and Post Pandemic Market Recovery Time.**

# %% [markdown]
# ### Check for non-finite values in the data

# %%
non_finite_mask = ~np.isfinite(company['Weekly Return'])
if non_finite_mask.any():
    print(f"Non-finite values found: {company['Weekly Return'][non_finite_mask]}")
# Out:
# Non-finite values found: Date
# 2020-01-02   NaN
# Name: Weekly Return, dtype: float64

# %% [markdown]
# One recorded dated 05/04/2018 has a Non-Finite value. Replacing the same with mean

# %% [markdown]
# ### Replace non-finite values with the mean

# %%
mean_return = np.nanmean(company['Weekly Return'])
company.loc[non_finite_mask, 'Weekly Return'] = mean_return

# %% [markdown]
# ### Now, let's get an overall look at the weekly return using a histogram.
#
# **We'll use seaborn to create both a histogram and kde plot on the same figure.**

# %%
plt.figure(figsize=(15, 25))

for i, company in enumerate(company_list_week, 1):
    plt.subplot(5, 1, i)
    company['Weekly Return'].hist(bins=50)
    plt.xlabel('Weekly Return')
    plt.ylabel('Frequency')
    plt.title(f'{company_name[i - 1]}')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation:
# **The Frequency so plotted for the above data, tend more to the positive side rather than the negative and the outliers seen are mostly due to the COVID-19 Pandemic.**
#
# **Reasons for other outliers, if any, have been stated in the above observations for scatter plot.**

# %% [markdown]
# # *3. What was the moving average of the various stocks?*

# %% [markdown]
# **The moving average (MA) is a simple technical analysis tool that smooths out price data by creating a constantly updated average price. The average is taken over a specific period of time, like 10 days, 20 minutes, 30 weeks, or any time period the trader chooses.**

# %% [markdown]
# **This code utilizes nested loops and the Pandas library to calculate moving averages (MAs) for a list of specified moving average days (ma_days) for a list of companies (company_list).**
#
# **Breakdown:**
#
# 1. Outer Loop (for ma in ma_days):
# This loop iterates over a list of moving average day values (ma_days), where each value represents the number of days to use for calculating the moving average.
# 2. Inner Loop (for company in company_list):
# Inside the outer loop, there is an inner loop that iterates over a list of company dataframes (company_list). Each dataframe represents data for a specific company.
# 3. Creating Column Names:
# Within the inner loop, a string variable column_name is created using f-strings. This string represents the name of the column that will store the moving average for the current company and the current moving average period (specified by ma).
# 4. Calculating Moving Averages:
# The code then calculates the moving average for the 'Adj Close' column of the current company's dataframe using the rolling() method with a window size of ma days. This rolling mean is calculated for each row in the dataframe.
# 5. Assigning the Moving Averages to Columns:
# The calculated moving average values are assigned to a new column in the current company's dataframe. This new column is named based on the column_name created earlier, which includes the specific moving average period.
# **So, for each company in the company_list, this code calculates and assigns moving averages for each of the specified ma_days, resulting in additional columns in each company's dataframe that contain the moving average values for different time periods.**
#
# **Also, the results fetched are being displayed in the form of graph for each company/index separately**

# %%
ma_days = [50, 120, 200]

for ma in ma_days:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=5, ncols=1)
fig.set_figheight(25)
fig.set_figwidth(15)

hcltech[['Adj Close', 'MA for 50 days', 'MA for 120 days', 'MA for 200 days']].plot(ax=axes[0])
axes[0].set_title('hcltech')

sunpharma[['Adj Close', 'MA for 50 days', 'MA for 120 days', 'MA for 200 days']].plot(ax=axes[1])
axes[1].set_title('sunpharma')

hdfcbank[['Adj Close', 'MA for 50 days', 'MA for 120 days', 'MA for 200 days']].plot(ax=axes[2])
axes[2].set_title('hdfcbank')

dlf[['Adj Close', 'MA for 50 days', 'MA for 120 days', 'MA for 200 days']].plot(ax=axes[3])
axes[3].set_title('dlf')

nifty50[['Adj Close', 'MA for 50 days', 'MA for 120 days', 'MA for 200 days']].plot(ax=axes[4])
axes[4].set_title('nifty50')

fig.tight_layout()

# %% [markdown]
# ### Comment:
# Moving averages are used to smooth out the price data and identify trends. They can also be used to identify support and resistance levels.
#
# Support is a price level where the price is likely to find buyers. Resistance is a price level where the price is likely to find sellers.
#
# **50-day moving average (50DMA):**
# The 50-day moving average (50DMA) is calculated by taking the average of a stock's closing prices over the past 50 trading days. It provides a short- to medium-term view of price trends. Traders and investors use the 50DMA to identify short- to medium-term trends and potential support and resistance levels. When the stock price is above the 50DMA, it suggests that the stock is in an uptrend. Conversely, when the price is below the 50DMA, it suggests a downtrend
#
# **120-day moving average (120DMA):**
# The 120-day moving average (120DMA) is calculated using the average of closing prices over the past 120 trading days. It provides a longer-term view compared to the 50DMA. The 120DMA is often used by medium- to long-term investors to identify longer-term trends and to help filter out short-term price fluctuations. Similar to the 50DMA, the relationship between the stock price and the 120DMA can indicate trend direction and potential support and resistance levels.
#
# **200-day moving average (200DMA):**
# The 200-day moving average (200DMA) is one of the most widely followed moving averages. It calculates the average closing price over the past 200 trading days. The 200DMA provides a long-term perspective and is often used to gauge the overall health of a stock or market index. When the stock price is above the 200DMA, it generally suggests a bullish trend, and when it's below, it indicates a bearish trend.

# %% [markdown]
# **Inference:**
# * HCLTech has been the strongest performer, followed by HDFC Bank.
# * HCLTech and HDFC Bank are both trading below their 50-day and 120-day moving averages, which suggests that they may be due for a pullback.
# * Sun Pharma is trading above its 200-day moving average, but below its 50-day & 120-day moving average.
# * Nifty 50 is trading below its 50-day, 120-day, and 200-day moving averages.

# %% [markdown]
# # 4. What was the correlation between different stocks closing prices?

# %% [markdown]
# **Correlation is a statistic that measures the degree to which two variables move in relation to each other which has a value that must fall between -1.0 and +1.0. Correlation measures association, but doesn’t show if x causes y or vice versa — or if the association is caused by a third factor.**
#
# **Now, we want to analyze the returns of all the stocks in our listwith all the ['Adj Close'] columns for each of the stocks dataframes.**

# %%
df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-01    569.400024    572.900024    566.849976    571.950012
# 2020-01-02    572.549988    575.000000    570.500000    573.549988
# 2020-01-03    574.000000    588.500000    572.849976    585.049988
# 2020-01-06    585.000000    592.200012    579.450012    582.000000
# 2020-01-07    582.000000    587.750000    579.049988    584.250000
# ...                  ...           ...           ...           ...
# 2024-02-23  22290.000000  22297.500000  22186.099609  22212.699219
# 2024-02-26  22169.199219  22202.150391  22075.150391  22122.050781
# 2024-02-27  22090.199219  22218.250000  22085.650391  22198.349609
# 2024-02-28  22214.099609  22229.150391  21915.849609  21951.150391
# 2024-02-29  21935.199219  22060.550781  21860.650391  21982.800781
#
#                Adj Close   Volume     Company/Index Name
# Date
# 2020-01-01    496.896912   918373  HCL Technologies Ltd.
# ...

# %%
# Calculate the percentage change in 'Adj Close' for each 'Company/Index Name'
df['Percent Change'] = df.groupby('Company/Index Name')['Adj Close'].pct_change()

# Pivot the DataFrame to show the result in separate columns for each 'Company/Index Name'
result_df = df.pivot(columns='Company/Index Name', values='Percent Change')

# Display the first few rows of the result DataFrame
print(result_df.head())
# Out:
# Company/Index Name  DLF Ltd.  HCL Technologies Ltd.  HDFC Bank Ltd.   NIFTY50  \
# Date
# 2020-01-01               NaN                    NaN             NaN       NaN
# 2020-01-02          0.027247               0.002797        0.006374  0.008184
# 2020-01-03         -0.022032               0.020051       -0.014261 -0.004523
# 2020-01-06         -0.033465              -0.005213       -0.021641 -0.019106
# 2020-01-07          0.020593               0.003866        0.015835  0.004995
#
# Company/Index Name  Sun Pharmaceutical Industries Ltd.
# Date
# 2020-01-01                                         NaN
# 2020-01-02                                    0.001497
# 2020-01-03                                    0.022187
# 2020-01-06                                   -0.010459
# 2020-01-07                                    0.014661

# %% [markdown]
# **Now, we can compare the weekly percentage return of two stocks to check how correlated. First let's see a stock compared to itself**

# %%
# Comparing "NIFTY50" to itself should show a perfectly linear relationship
sns.jointplot(x='NIFTY50', y='NIFTY50', data=result_df, kind='scatter', color='seagreen')

# %%
# We'll use joinplot to compare the daily returns of "HCL Technologies Ltd." and "NIFTY50"
sns.jointplot(x='HCL Technologies Ltd.', y='NIFTY50', data=result_df, kind='scatter')

# %% [markdown]
# **So now, we can see that if two stocks are perfectly (and positivley) correlated with each other a linear relationship bewteen its weekly return values should occur.**

# %% [markdown]
# **The code below uses the sns.pairplot() function from the Seaborn library to create a pairwise plot of all the numeric variables in the result_df DataFrame. A pairwise plot is a grid of plots that shows the relationship between each pair of variables in the dataset.**
#
# **The kind='reg' argument tells the sns.pairplot() function to create scatter plots with linear regression lines. This can be helpful for identifying the linear relationships between the variables.**

# %%
# Calling pairplot on our DataFrame for an automatic visual analysis of all the comparisons
sns.pairplot(result_df, kind='reg')

# Set the font size for X and Y-axis titles
plt.rcParams['axes.labelsize'] = 8 

# Display the plot
plt.show()

# %% [markdown]
# ### **Observations:**
# **Above we can see all the relationships on daily returns between all the stocks. A quick glance shows an interesting correlation between NIFTY50 and HDFC Bank Ltd. weekly returns. This relation exists because HDFC Bank Ltd. is one of the major contributors in NIFTY50 Index.**
#
# **It might be interesting to investigate that individual comparison.**

# %% [markdown]
# #### **To get actual numerical values for the correlation between the stocks' weekly return values, we do a correlation plot. By comparing the Adjusted closing prices, we can see interesting relationship between different stocks.**

# %% [markdown]
# ### Plotting the above Numerical Values in a HeatMap

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
sns.heatmap(result_df.corr(), annot=True, cmap='Blues')
plt.title('Correlation of stock Weekly return')
# Out:
# Text(0.5, 1.0, 'Correlation of stock Weekly return')

# %% [markdown]
# ### Observations:
#
# **Investors use the correlation of stocks to measure the risk of their portfolio and to diversify their investments.**
#
# In other words, investors want to know how much the price of one stock will move in relation to the price of another stock. If the two stocks are highly correlated, then they will move in the same direction, which means that the investor's portfolio will be more risky. However, if the two stocks are not correlated, then they will move in different directions, which can help to reduce the risk of the portfolio.
#
# * **DLF Ltd : It is less aligned with movement in Sun Pharma and HCL but it is moving in direction with NIFTY 50.**
#
# * **HCL TECH: It is not majorly effected with change in any of the stocks selected apart from NIFTY 50.**
#
# * **HDFC BANK: HDFC Bank have major impact on movement of NIFTY 50 as it has more weightage in Index than any other stock.**
#
# * **NIFTY50: It gets influenced by the weightage of individual shares, with HDFC Bank and DLF exhibiting stronger correlations.**
#
# * **Sun Pharma: It is not much correlated with any of another stock as it does show major unidirectional change with other shares, HDFC and HCL have adverse effect on this stock price most of the time.**

# %% [markdown]
# # 5. *How much value do we put at risk by investing in a particular stock?*

# %% [markdown]
# **The code creates a scatter plot of the rets DataFrame, with the mean return on the X-axis and the standard deviation of the return on the Y-axis. The size of each point is proportional to the area variable.**

# %%
rets = result_df.dropna() # result_df is the dataframe of daily percentange change of 'Adj Close' of all stocks

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='->', color='red', connectionstyle='arc3,rad=0.3'))

# %% [markdown]
# ### Inference:
# **It is usually said that "Lower the risk, Lower the return and Higher the risk, Higher the return", but from the above graph we can see that HCL Technologies Ltd. is defying the quote and with medium risk is providing the highest return**
#
# **DLF here is most riskiest stock as it has a daily risk of 2.8% movement in stock, it indicates that the stock is more volatile even in long term, but it is also having good returns.**
#
# **On the other hand, SunPharma and HDFC have less risk and safer returns as compared to HCL and DLF. These are more beneficial for risk averting investors**

# %% [markdown]
# # 6. Predicting the closing price stock price

# %% [markdown]
# ## ARIMA Model

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import math

# %% [markdown]
# ### Defining Functions
# #### (These functions are going to be used multiple times, hence defining at the beginning of Model building)

# %% [markdown]
# #### Function for Testing Stationarity

# %%
# Check for stationarity using the Augmented Dickey-Fuller test
def test_stationarity(timeseries):
    """
    Performs the Augmented Dickey-Fuller test for stationarity.

    Args:
        timeseries: A Pandas Series or NumPy array containing the time series data.

    Returns:
        None.
        
    Example Usage:
        test_stationarity(timeseries_data)
    """
    # Perform Dickey-Fuller test:
    result = adfuller(timeseries, autolag='AIC')
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'  {key}: {value}')

# %% [markdown]
# #### Function for Making Predictions

# %%
def make_predictions(model, test):
    """
    Makes predictions for the test data.

    Args:
        model: A fitted time series model.
        test: A Pandas Series or NumPy array containing the test data.

    Returns:
        A Pandas DataFrame containing the predictions.
            
    Example Usage:
        # Make predictions for the next 10 time steps.
        predictions = make_predictions(model, np.arange(100, 110))
    """
    # Make predictions for the test data.
    start = len(model.fittedvalues)  # Use the length of the fitted values as the starting point
    end = start + len(test) - 1
    predictions = model.predict(start=start, end=end, typ='levels')

    # Return the predictions as a pandas DataFrame.
    return predictions

# %% [markdown]
# ### SUNPHARMA

# %%
data_sunpharma = sunpharma[['Adj Close']]
data_sunpharma
# Out:
#               Adj Close
# Date
# 2020-01-01   413.836670
# 2020-01-02   414.456024
# 2020-01-03   423.651367
# 2020-01-06   419.220459
# 2020-01-07   425.366486
# ...                 ...
# 2024-02-23  1561.250000
# 2024-02-26  1556.949951
# 2024-02-27  1582.750000
# 2024-02-28  1573.849976
# 2024-02-29  1577.949951
#
# [1034 rows x 1 columns]

# %%
# Plot the 'Adj Close' column
plt.figure(figsize=(12, 6))
plt.plot(data_sunpharma['Adj Close'], label='Adjusted Close Price')
plt.title('Sunpharma Stock Price')
plt.legend()
plt.show()

# %%
# Calling Test stationarity function
test_stationarity(data_sunpharma['Adj Close'])
# Out:
# ADF Statistic: 1.8554502587126842
# p-value: 0.9984528788710266
# Critical Values:
#   1%: -3.4367023644255537
#   5%: -2.864344690221488
#   10%: -2.5682633351736674

# %% [markdown]
# **As the p-value is greater than 0.05, the series is non-stationary. We will now make it stationary by differencing the data.**

# %%
# Let's difference the data once (d=1) to make it stationary.
data_sunpharma['Adj Close Diff'] = data_sunpharma['Adj Close'].diff()
# Out:
# C:\Users\prave\AppData\Local\Temp\ipykernel_17800\1669218354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sunpharma['Adj Close Diff'] = data_sunpharma['Adj Close'].diff()

# %%
# Test stationarity of the differenced series
test_stationarity(data_sunpharma['Adj Close Diff'].dropna())
# Out:
# ADF Statistic: -34.12513688432278
# p-value: 0.0
# Critical Values:
#   1%: -3.4367023644255537
#   5%: -2.864344690221488
#   10%: -2.5682633351736674

# %% [markdown]
# **After differencing the data once (d = 1) the data has become stationary, Now we will plot the ACF and PACF plots.**

# %%
# Create a new figure for ACF
plt.figure(figsize=(12, 4))
plot_acf(data_sunpharma['Adj Close Diff'].dropna(), lags=40)
plt.title('ACF')

# Create a new figure for PACF
plt.figure(figsize=(12, 4))
plot_pacf(data_sunpharma['Adj Close Diff'].dropna(), lags=40)
plt.title('PACF')

# Show the plots
plt.show()
# Out:
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Split the data into train and test sets
train_size_sunpharma = int(len(data_sunpharma) * 0.8)
train_sunpharma, test_sunpharma = data_sunpharma[:train_size_sunpharma], data_sunpharma[train_size_sunpharma:]

# %%
train_sunpharma.head()
# Out:
#              Adj Close  Adj Close Diff
# Date
# 2020-01-01  413.836670             NaN
# 2020-01-02  414.456024        0.619354
# 2020-01-03  423.651367        9.195343
# 2020-01-06  419.220459       -4.430908
# 2020-01-07  425.366486        6.146027

# %%
test_sunpharma.head()
# Out:
#              Adj Close  Adj Close Diff
# Date
# 2023-05-03  954.761353       -9.363281
# 2023-05-04  965.065918       10.304565
# 2023-05-05  961.548523       -3.517395
# 2023-05-08  953.027405       -8.521118
# 2023-05-09  948.667786       -4.359619

# %%
# Specify a range for p and q
p_values = range(0, 10)
q_values = range(0, 10)

best_aic = float("inf")
best_order = None

for p in p_values:
    for q in q_values:
        try:
            model = sm.tsa.ARIMA(train_sunpharma['Adj Close Diff'], order=(p, 1, q))
            model_fit = model.fit()
            aic = model_fit.aic
            if aic < best_aic:
                best_aic = aic
                best_order = (p, 1, q)
        except:
            continue

print("Best ARIMA Order (p, d, q):", best_order)
# Out:
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
def build_arima_model(data, order=(0, 1, 1)):
    """
    Builds an ARIMA model for the given data.

    Args:
        data: A Pandas DataFrame containing the time series data.
        order: A tuple containing the order of the ARIMA model (p, d, q).

    Returns:
        A fitted ARIMA model.
        
    Example usage:
        # Build the ARIMA model.
        model_fit = build_arima_model(data)
    """
    # Create the ARIMA model.
    model = sm.tsa.ARIMA(data['Adj Close Diff'], order=order)
    # Fit the model to the data.
    model_fit = model.fit()
    return model_fit

# %%
# Build the ARIMA model.
model_sunpharma = build_arima_model(train_sunpharma)
# Out:
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Predicting the 'Adj Close' values for test
predictions_sunpharma = make_predictions(model_sunpharma, test_sunpharma)

# Create a DataFrame to store the predictions.
predictions_df_sunpharma = pd.DataFrame({'Predictions': predictions_sunpharma})
# Out:
# C:\Users\prave\anaconda3\envs\tensorflow3.9.5\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Initialize a new column for the integrated predictions
predictions_df_sunpharma['Integrated_Predictions'] = None

# Initialize the first value in the integrated predictions column with the initial value
predictions_df_sunpharma.at[990, 'Integrated_Predictions'] = 912.9122

# %%
predictions_df_sunpharma
# Out:
#       Predictions Integrated_Predictions
# 827      0.662533                   None
# 828      0.662533                   None
# 829      0.662533                   None
# 830      0.662533                   None
# 831      0.662533                   None
# ...           ...                    ...
# 1029     0.662533             938.750996
# 1030     0.662533             939.413529
# 1031     0.662533             940.076063
# 1032     0.662533             940.738596
# 1033     0.662533             941.401129
#
# [207 rows x 2 columns]

# %%
len(predictions_df_sunpharma)
# Out:
# 207

# %%
""" # Loop through the DataFrame to perform the integration
for i in range(991, 1238):
    diff_prediction_sunpharma = predictions_df_sunpharma.at[i, 'Predictions']
    integrated_prediction_sunpharma = predictions_df_sunpharma.at[i - 1, 'Integrated_Predictions'] + diff_prediction_sunpharma
    predictions_df_sunpharma.at[i, 'Integrated_Predictions'] = integrated_prediction_sunpharma"""
    
    
for i in range(991, 1238):
    try:
        diff_prediction_sunpharma = predictions_df_sunpharma.at[i, 'Predictions']
        # Check if the previous integrated prediction is not None before performing addition
        if predictions_df_sunpharma.at[i - 1, 'Integrated_Predictions'] is not None:
            integrated_prediction_sunpharma = predictions_df_sunpharma.at[i - 1, 'Integrated_Predictions'] + diff_prediction_sunpharma
        else:
            integrated_prediction_sunpharma = None  # Handle the case where previous prediction is None
        predictions_df_sunpharma.at[i, 'Integrated_Predictions'] = integrated_prediction_sunpharma
    except KeyError:
        print(f"KeyError occurred at index: {i}")
# Out:
# KeyError occurred at index: 1034
# KeyError occurred at index: 1035
# KeyError occurred at index: 1036
# KeyError occurred at index: 1037
# KeyError occurred at index: 1038
# KeyError occurred at index: 1039
# KeyError occurred at index: 1040
# KeyError occurred at index: 1041
# KeyError occurred at index: 1042
# KeyError occurred at index: 1043
# KeyError occurred at index: 1044
# KeyError occurred at index: 1045
# KeyError occurred at index: 1046
# KeyError occurred at index: 1047
# KeyError occurred at index: 1048
# KeyError occurred at index: 1049
# KeyError occurred at index: 1050
# KeyError occurred at index: 1051
# KeyError occurred at index: 1052
# KeyError occurred at index: 1053
# KeyError occurred at index: 1054
# KeyError occurred at index: 1055
# KeyError occurred at index: 1056
# KeyError occurred at index: 1057
# KeyError occurred at index: 1058
# KeyError occurred at index: 1059
# KeyError occurred at index: 1060
# KeyError occurred at index: 1061
# ...

# %%
predictions_df_sunpharma.head()
# Out:
#      Predictions Integrated_Predictions
# 827     0.662533                   None
# 828     0.662533                   None
# 829     0.662533                   None
# 830     0.662533                   None
# 831     0.662533                   None

# %%
""" # Calculate Mean Squared Error (MSE)
mse_sunpharma = mean_squared_error(test_sunpharma['Adj Close'], predictions_df_sunpharma['Integrated_Predictions'])

# Calculate Root Mean Squared Error (RMSE)
rmse_sunpharma = math.sqrt(mse_sunpharma)

print(f"Mean Squared Error (MSE): {mse_sunpharma}")
print(f"Root Mean Squared Error (RMSE): {rmse_sunpharma}")"""


# Remove NaN values from both true and predicted values
true_values = test_sunpharma['Adj Close'].dropna()
predicted_values = predictions_df_sunpharma['Integrated_Predictions'].dropna()

# Calculate Mean Squared Error (MSE)
mse_sunpharma = mean_squared_error(true_values, predicted_values)

# Calculate Root Mean Squared Error (RMSE)
rmse_sunpharma = np.sqrt(mse_sunpharma)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 16
#      13 predicted_values = predictions_df_sunpharma['Integrated_Predictions'].dropna()
#      15 # Calculate Mean Squared Error (MSE)
# ---> 16 mse_sunpharma = mean_squared_error(true_values, predicted_values)
#      18 # Calculate Root Mean Squared Error (RMSE)
#      19 rmse_sunpharma = np.sqrt(mse_sunpharma)
#
# File ~\anaconda3\envs\tensorflow3.9.5\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
# ...

# %%
# Plot the test set and predicted values
plt.figure(figsize=(12, 6))
plt.plot(train_sunpharma.index, train_sunpharma['Adj Close'], label='Train')
plt.plot(test_sunpharma.index, test_sunpharma['Adj Close'], label='Test')
plt.plot(test_sunpharma.index, predictions_df_sunpharma['Integrated_Predictions'], label='Integrated_Predictions')
plt.title('ARIMA Model Predictions vs. Actuals')
plt.legend()
plt.show()

# %% [markdown]
# ### HCLTECH

# %%
data_hcltech = hcltech[['Adj Close']]
data_hcltech

# %%
# Plot the 'Adj Close' column
plt.figure(figsize=(12, 6))
plt.plot(data_hcltech['Adj Close'], label='Adjusted Close Price')
plt.title('HCLTECH Stock Price')
plt.legend()
plt.show()

# %%
# Test stationarity
test_stationarity(data_hcltech['Adj Close'])

# %% [markdown]
# **As the p-value is greater than 0.05, the series is not stationary. We will now make it stationary by differencing the data.**

# %%
# Let's difference the data once (d=1) to make it stationary.
data_hcltech['Adj Close Diff'] = data_hcltech['Adj Close'].diff()

# %%
# Test stationarity of the differenced series
test_stationarity(data_hcltech['Adj Close Diff'].dropna())

# %% [markdown]
# **After differencing the data once (d = 1) the data has become stationary, Now we will plot the ACF and PACF plots**

# %%
# Create a new figure for ACF
plt.figure(figsize=(12, 4))
plot_acf(data_hcltech['Adj Close Diff'].dropna(), lags=40)
plt.title('ACF')

# Create a new figure for PACF
plt.figure(figsize=(12, 4))
plot_pacf(data_hcltech['Adj Close Diff'].dropna(), lags=40)
plt.title('PACF')

# Show the plots
plt.show()

# %%
# Split the data into train and test sets
train_size_hcltech = int(len(data_hcltech) * 0.8)
train_hcltech, test_hcltech = data_hcltech[:train_size_hcltech], data_hcltech[train_size_hcltech:]

# %%
train_hcltech.head()

# %%
test_hcltech.head()

# %%
# Specify a range for p and q
p_values = range(0, 10)
q_values = range(0, 10)

best_aic = float("inf")
best_order = None

for p in p_values:
    for q in q_values:
        try:
            model = sm.tsa.ARIMA(train_hcltech['Adj Close Diff'], order=(p, 1, q))
            model_fit = model.fit()
            aic = model_fit.aic
            if aic < best_aic:
                best_aic = aic
                best_order = (p, 1, q)
        except:
            continue

print("Best ARIMA Order (p, d, q):", best_order)

# %%
def build_arima_model(data, order=(6, 1, 7)):
    """
    Builds an ARIMA model for the given data.

    Args:
        data: A Pandas DataFrame containing the time series data.
        order: A tuple containing the order of the ARIMA model (p, d, q).

    Returns:
        A fitted ARIMA model.
        
    Example usage:
        # Build the ARIMA model.
        model_fit = build_arima_model(data)
    """
    # Create the ARIMA model.
    model = sm.tsa.ARIMA(data['Adj Close Diff'], order=order)
    # Fit the model to the data.
    model_fit = model.fit()
    return model_fit

# %%
# Build the ARIMA model.
model_hcltech = build_arima_model(train_hcltech)

# %%
predictions_hcltech = make_predictions(model_hcltech, test_hcltech)

# Create a DataFrame to store the predictions.
predictions_df_hcltech = pd.DataFrame({'Predictions': predictions_hcltech})

# %%
# Initialize a new column for the integrated predictions
predictions_df_hcltech['Integrated_Predictions'] = None

# Initialize the first value in the integrated predictions column with the initial value
predictions_df_hcltech.at[990, 'Integrated_Predictions'] = 1104.324

# %%
len(predictions_df_hcltech)

# %%
# Loop through the DataFrame to perform the integration
for i in range(991, 1238):
    diff_prediction_hcltech = predictions_df_hcltech.at[i, 'Predictions']
    integrated_prediction_hcltech = predictions_df_hcltech.at[i - 1, 'Integrated_Predictions'] + diff_prediction_hcltech
    predictions_df_hcltech.at[i, 'Integrated_Predictions'] = integrated_prediction_hcltech

# %%
predictions_df_hcltech.head()

# %%
# Calculate Mean Squared Error (MSE)
mse_hcltech = mean_squared_error(test_hcltech['Adj Close'], predictions_df_hcltech['Integrated_Predictions'])

# Calculate Root Mean Squared Error (RMSE)
rmse_hcltech = math.sqrt(mse_hcltech)

print(f"Mean Squared Error (MSE): {mse_hcltech}")
print(f"Root Mean Squared Error (RMSE): {rmse_hcltech}")

# %%
# Plot the test set and predicted values
plt.figure(figsize=(12, 6))
plt.plot(train_hcltech.index, train_hcltech['Adj Close'], label='Train')
plt.plot(test_hcltech.index, test_hcltech['Adj Close'], label='Test')
plt.plot(test_hcltech.index, predictions_df_hcltech['Integrated_Predictions'], label='Integrated_Predictions')
plt.title('ARIMA Model Predictions vs. Actuals')
plt.legend()
plt.show()

# %% [markdown]
# ### HDFCBANK

# %%
data_hdfcbank = hdfcbank[['Adj Close']]
data_hdfcbank

# %%
# Plot the 'Adj Close' column
plt.figure(figsize=(12, 6))
plt.plot(data_hdfcbank['Adj Close'], label='Adjusted Close Price')
plt.title('HDFCBank Stock Price')
plt.legend()
plt.show()

# %%
# Test stationarity
test_stationarity(data_hdfcbank['Adj Close'])

# %% [markdown]
# **As the p-value is greater than 0.05, the series is not stationary. We will now make it stationary by differencing the data.**

# %%
# Let's difference the data once (d=1) to make it stationary.
data_hdfcbank['Adj Close Diff'] = data_hdfcbank['Adj Close'].diff()

# %%
# Test stationarity of the differenced series
test_stationarity(data_hdfcbank['Adj Close Diff'].dropna())

# %% [markdown]
# **After differencing the data once (d = 1) the data has become stationary, Now we will plot the ACF and PACF plots.**

# %%
# Create a new figure for ACF
plt.figure(figsize=(12, 4))
plot_acf(data_hdfcbank['Adj Close Diff'].dropna(), lags=40)
plt.title('ACF')

# Create a new figure for PACF
plt.figure(figsize=(12, 4))
plot_pacf(data_hdfcbank['Adj Close Diff'].dropna(), lags=40)
plt.title('PACF')

# Show the plots
plt.show()

# %%
# Split the data into train and test sets
train_size_hdfcbank = int(len(data_hdfcbank) * 0.8)
train_hdfcbank, test_hdfcbank = data_hdfcbank[:train_size_hdfcbank], data_hdfcbank[train_size_hdfcbank:]

# %%
train_hdfcbank.head()

# %%
test_hdfcbank.head()

# %%
# Specify a range for p and q
p_values = range(0, 10)
q_values = range(0, 10)

best_aic = float("inf")
best_order = None

for p in p_values:
    for q in q_values:
        try:
            model = sm.tsa.ARIMA(train_hdfcbank['Adj Close Diff'], order=(p, 1, q))
            model_fit = model.fit()
            aic = model_fit.aic
            if aic < best_aic:
                best_aic = aic
                best_order = (p, 1, q)
        except:
            continue

print("Best ARIMA Order (p, d, q):", best_order)

# %%
def build_arima_model(data, order=(4, 1, 8)):
    """
    Builds an ARIMA model for the given data.

    Args:
        data: A Pandas DataFrame containing the time series data.
        order: A tuple containing the order of the ARIMA model (p, d, q).

    Returns:
        A fitted ARIMA model.
        
    Example usage:
        # Build the ARIMA model.
        model_fit = build_arima_model(data)
    """
    # Create the ARIMA model.
    model = sm.tsa.ARIMA(data['Adj Close Diff'], order=order)
    # Fit the model to the data.
    model_fit = model.fit()
    return model_fit

# %%
# Build the ARIMA model.
model_hdfcbank = build_arima_model(train_hdfcbank)

# %%
# Making Predictions
predictions_hdfcbank = make_predictions(model_hdfcbank, test_hdfcbank)

# Create a DataFrame to store the predictions.
predictions_df_hdfcbank = pd.DataFrame({'Predictions': predictions_hdfcbank})

# %%
# Initialize a new column for the integrated predictions
predictions_df_hdfcbank['Integrated_Predictions'] = None

# Initialize the first value in the integrated predictions column with the initial value
predictions_df_hdfcbank.at[990, 'Integrated_Predictions'] = 1619.189

# %%
len(predictions_df_hdfcbank)

# %%
# Loop through the DataFrame to perform the integration
for i in range(991, 1238):
    diff_prediction_hdfcbank = predictions_df_hdfcbank.at[i, 'Predictions']
    integrated_prediction_hdfcbank = predictions_df_hdfcbank.at[i - 1, 'Integrated_Predictions'] + diff_prediction_sunpharma
    predictions_df_hdfcbank.at[i, 'Integrated_Predictions'] = integrated_prediction_hdfcbank

# %%
predictions_df_hdfcbank.head()

# %%
# Calculate Mean Squared Error (MSE)
mse_hdfcbank = mean_squared_error(test_hdfcbank['Adj Close'], predictions_df_hdfcbank['Integrated_Predictions'])

# Calculate Root Mean Squared Error (RMSE)
rmse_hdfcbank = math.sqrt(mse_hdfcbank)

print(f"Mean Squared Error (MSE): {mse_hdfcbank}")
print(f"Root Mean Squared Error (RMSE): {rmse_hdfcbank}")

# %%
# Plot the test set and predicted values
plt.figure(figsize=(12, 6))
plt.plot(train_hdfcbank.index, train_hdfcbank['Adj Close'], label='Train')
plt.plot(test_hdfcbank.index, test_hdfcbank['Adj Close'], label='Test')
plt.plot(test_hdfcbank.index, predictions_df_hdfcbank['Integrated_Predictions'], label='Integrated_Predictions')
plt.title('ARIMA Model Predictions vs. Actuals')
plt.legend()
plt.show()

# %% [markdown]
# ### DLF

# %%
data_dlf = dlf[['Adj Close']]
data_dlf

# %%
# Plot the 'Adj Close' column
plt.figure(figsize=(12, 6))
plt.plot(data_dlf['Adj Close'], label='Adjusted Close Price')
plt.title('DLF Stock Price')
plt.legend()
plt.show()

# %%
# Test stationarity
test_stationarity(data_dlf['Adj Close'])

# %% [markdown]
# **As the p-value is greater than 0.05, the series is not stationary. We will now make it stationary by differencing the data**

# %%
# Let's difference the data once (d=1) to make it stationary.
data_dlf['Adj Close Diff'] = data_dlf['Adj Close'].diff()

# %%
# Test stationarity of the differenced series
test_stationarity(data_dlf['Adj Close Diff'].dropna())

# %% [markdown]
# **After differencing the data once (d = 1) the data has become stationary, Now we will plot the ACF and PACF plots**

# %%
# Create a new figure for ACF
plt.figure(figsize=(12, 4))
plot_acf(data_dlf['Adj Close Diff'].dropna(), lags=40)
plt.title('ACF')

# Create a new figure for PACF
plt.figure(figsize=(12, 4))
plot_pacf(data_dlf['Adj Close Diff'].dropna(), lags=40)
plt.title('PACF')

# Show the plots
plt.show()

# %%
# Split the data into train and test sets
train_size_dlf = int(len(data_dlf) * 0.8)
train_dlf, test_dlf = data_dlf[:train_size_dlf], data_dlf[train_size_dlf:]

# %%
train_dlf.head()

# %%
test_dlf.head()

# %%
# Specify a range for p and q
p_values = range(0, 10)
q_values = range(0, 10)

best_aic = float("inf")
best_order = None

for p in p_values:
    for q in q_values:
        try:
            model = sm.tsa.ARIMA(train_dlf['Adj Close Diff'], order=(p, 1, q))
            model_fit = model.fit()
            aic = model_fit.aic
            if aic < best_aic:
                best_aic = aic
                best_order = (p, 1, q)
        except:
            continue

print("Best ARIMA Order (p, d, q):", best_order)

# %%
def build_arima_model(data, order=(2, 1, 3)):
    """
    Builds an ARIMA model for the given data.

    Args:
        data: A Pandas DataFrame containing the time series data.
        order: A tuple containing the order of the ARIMA model (p, d, q).

    Returns:
        A fitted ARIMA model.
        
    Example usage:
        # Build the ARIMA model.
        model_fit = build_arima_model(data)
    """
    # Create the ARIMA model.
    model = sm.tsa.ARIMA(data['Adj Close Diff'], order=order)
    # Fit the model to the data.
    model_fit = model.fit()
    return model_fit

# %%
# Build the ARIMA model.
model_dlf = build_arima_model(train_dlf)

# %%
# Making Predictions
predictions_dlf = make_predictions(model_dlf, test_dlf)

# Create a DataFrame to store the predictions.
predictions_df_dlf = pd.DataFrame({'Predictions': predictions_dlf})

# %%
# Initialize a new column for the integrated predictions
predictions_df_dlf['Integrated_Predictions'] = None

# Initialize the first value in the integrated predictions column with the initial value
predictions_df_dlf.at[990, 'Integrated_Predictions'] = 381.267

# %%
len(predictions_df_dlf)

# %%
# Loop through the DataFrame to perform the integration
for i in range(991, 1238):
    diff_prediction_dlf = predictions_df_dlf.at[i, 'Predictions']
    integrated_prediction_dlf = predictions_df_dlf.at[i - 1, 'Integrated_Predictions'] + diff_prediction_dlf
    predictions_df_dlf.at[i, 'Integrated_Predictions'] = integrated_prediction_dlf

# %%
predictions_df_dlf.head()

# %%
# Calculate Mean Squared Error (MSE)
mse_dlf = mean_squared_error(test_dlf['Adj Close'], predictions_df_dlf['Integrated_Predictions'])

# Calculate Root Mean Squared Error (RMSE)
rmse_dlf = math.sqrt(mse_dlf)

print(f"Mean Squared Error (MSE): {mse_dlf}")
print(f"Root Mean Squared Error (RMSE): {rmse_dlf}")

# %%
# Plot the test set and predicted values
plt.figure(figsize=(12, 6))
plt.plot(train_dlf.index, train_dlf['Adj Close'], label='Train')
plt.plot(test_dlf.index, test_dlf['Adj Close'], label='Test')
plt.plot(test_dlf.index, predictions_df_dlf['Integrated_Predictions'], label='Integrated_Predictions')
plt.title('ARIMA Model Predictions vs. Actuals')
plt.legend()
plt.show()

# %% [markdown]
# ### NIFTY50

# %%
data_nifty50 = nifty50[['Adj Close']].dropna()
data_nifty50

# %%
# Plot the 'Adj Close' column
plt.figure(figsize=(12, 6))
plt.plot(data_nifty50['Adj Close'], label='Adjusted Close Price')
plt.title('NIFTY50 Stock Price')
plt.legend()
plt.show()

# %%
# Test stationarity
test_stationarity(data_nifty50['Adj Close'])

# %% [markdown]
# **As the p-value is greater than 0.05, the series is not stationary. We will now make it stationary by differencing the data**

# %%
# Let's difference the data once (d=1) to make it stationary.
data_nifty50['Adj Close Diff'] = data_nifty50['Adj Close'].diff()

# %%
# Test stationarity of the differenced series
test_stationarity(data_nifty50['Adj Close Diff'].dropna())

# %% [markdown]
# **After differencing the data thrice (d = 1) the data has become stationary, Now we will plot the ACF and PACF plots**

# %%
# Create a new figure for ACF
plt.figure(figsize=(12, 4))
plot_acf(data_nifty50['Adj Close Diff'].dropna(), lags=40)
plt.title('ACF')

# Create a new figure for PACF
plt.figure(figsize=(12, 4))
plot_pacf(data_nifty50['Adj Close Diff'].dropna(), lags=40)
plt.title('PACF')

# Show the plots
plt.show()

# %%
# Split the data into train and test sets
train_size_nifty50 = int(len(data_nifty50) * 0.8)
train_nifty50, test_nifty50 = data_nifty50[:train_size_nifty50], data_nifty50[train_size_nifty50:]

# %%
train_nifty50.head()

# %%
test_nifty50.head()

# %%
# Specify a range for p and q
p_values = range(0, 10)
q_values = range(0, 10)

best_aic = float("inf")
best_order = None

for p in p_values:
    for q in q_values:
        try:
            model = sm.tsa.ARIMA(train_nifty50['Adj Close Diff'], order=(p, 1, q))
            model_fit = model.fit()
            aic = model_fit.aic
            if aic < best_aic:
                best_aic = aic
                best_order = (p, 1, q)
        except:
            continue

print("Best ARIMA Order (p, d, q):", best_order)

# %%
def build_arima_model(data, order=(2, 1, 5)):
    """
    Builds an ARIMA model for the given data.

    Args:
        data: A Pandas DataFrame containing the time series data.
        order: A tuple containing the order of the ARIMA model (p, d, q).

    Returns:
        A fitted ARIMA model.
        
    Example usage:
        # Build the ARIMA model.
        model_fit = build_arima_model(data)
    """
    # Create the ARIMA model.
    model = sm.tsa.ARIMA(data['Adj Close Diff'], order=order)
    # Fit the model to the data.
    model_fit = model.fit()
    return model_fit

# %%
# Build the ARIMA model.
model_nifty50 = build_arima_model(train_nifty50)

# %%
# Making Predictions
predictions_nifty50 = make_predictions(model_nifty50, test_nifty50)

# Create a DataFrame to store the predictions.
predictions_df_nifty50 = pd.DataFrame({'Predictions': predictions_nifty50})

# %%
# Initialize a new column for the integrated predictions
predictions_df_nifty50['Integrated_Predictions'] = None

# Initialize the first value in the integrated predictions column with the initial value
predictions_df_nifty50.at[988, 'Integrated_Predictions'] = 17957.40

# %%
len(predictions_df_nifty50)

# %%
# Loop through the DataFrame to perform the integration
for i in range(989, 1235):
    diff_prediction_nifty50 = predictions_df_nifty50.at[i, 'Predictions']
    integrated_prediction_nifty50 = predictions_df_nifty50.at[i - 1, 'Integrated_Predictions'] + diff_prediction_nifty50
    predictions_df_nifty50.at[i, 'Integrated_Predictions'] = integrated_prediction_nifty50

# %%
predictions_df_nifty50.head()

# %%
# Calculate Mean Squared Error (MSE)
mse_nifty50 = mean_squared_error(test_nifty50['Adj Close'], predictions_df_nifty50['Integrated_Predictions'])

# Calculate Root Mean Squared Error (RMSE)
rmse_nifty50 = math.sqrt(mse_nifty50)

print(f"Mean Squared Error (MSE): {mse_nifty50}")
print(f"Root Mean Squared Error (RMSE): {rmse_nifty50}")

# %%
# Plot the test set and predicted values
plt.figure(figsize=(12, 6))
plt.plot(train_nifty50.index, train_nifty50['Adj Close'], label='Train')
plt.plot(test_nifty50.index, test_nifty50['Adj Close'], label='Test')
plt.plot(test_nifty50.index, predictions_df_nifty50['Integrated_Predictions'], label='Integrated_Predictions')
plt.title('ARIMA Model Predictions vs. Actuals')
plt.legend()
plt.show()

# %% [markdown]
# ## PROPHET Model

# %%
from prophet import Prophet
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# ### SUNPHARMA

# %%
# Reseting the index
sunpharma_reset = sunpharma.reset_index()
sunpharma_reset

# %%
prophet_sunpharma = sunpharma_reset[['Date','Adj Close']]
prophet_sunpharma

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
prophet_sunpharma.rename(columns={'Adj Close': 'y'}, inplace=True)
prophet_sunpharma.rename(columns={'Date': 'ds'}, inplace=True)

# %%
# Split the data into train and test sets
prophet_train_size_sunpharma = int(len(prophet_sunpharma) * 0.8)
prophet_train_sunpharma, prophet_test_sunpharma = prophet_sunpharma[:prophet_train_size_sunpharma], prophet_sunpharma[prophet_train_size_sunpharma:]

# %%
prophet_train_sunpharma.head()

# %%
prophet_test_sunpharma.head()

# %%
# Create a Prophet model
prophet_model_sunpharma = Prophet()

# Fit the model to your data
prophet_model_sunpharma.fit(prophet_train_sunpharma)

# %%
# Make predictions on the test set
prophet_future_sunpharma = prophet_model_sunpharma.make_future_dataframe(periods=len(prophet_test_sunpharma))
prophet_forecast_sunpharma = prophet_model_sunpharma.predict(prophet_future_sunpharma)

# %%
# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
y_true_sunpharma = prophet_test_sunpharma['y'].values
y_pred_sunpharma = prophet_forecast_sunpharma.loc[prophet_train_size_sunpharma:, 'yhat'].values
prophet_mse_sunpharma = mean_squared_error(y_true_sunpharma, y_pred_sunpharma)
prophet_rmse_sunpharma = sqrt(prophet_mse_sunpharma)

print(f'Mean Squared Error (MSE): {prophet_mse_sunpharma:.2f}')
print(f'Root Mean Squared Error (RMSE): {prophet_rmse_sunpharma:.2f}')

# %%
# Plotting train, test actual, and test predicted values with confidence intervals
fig, ax = plt.subplots(figsize=(12, 6))

# Plot training data
ax.plot(prophet_train_sunpharma['ds'], prophet_train_sunpharma['y'], label='Train', color='blue')

# Plot test data
ax.plot(prophet_test_sunpharma['ds'], prophet_test_sunpharma['y'], label='Test', color='green')

# Plot predicted values and uncertainty for the test data
ax.plot(prophet_test_sunpharma['ds'], prophet_forecast_sunpharma.loc[prophet_train_size_sunpharma:, 'yhat'], label='Predicted', color='red')
ax.fill_between(prophet_test_sunpharma['ds'], prophet_forecast_sunpharma.loc[prophet_train_size_sunpharma:, 'yhat_lower'], prophet_forecast_sunpharma.loc[prophet_train_size_sunpharma:, 'yhat_upper'], color='pink', alpha=0.5, label='Confidence Interval')

# Set labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('Adj Close Price')
ax.set_title('Prophet Model for Sun Pharmaceuticals Industries Ltd. Stock Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### HCLTECH

# %%
# Reseting the Index
hcltech_reset = hcltech.reset_index()
hcltech_reset

# %%
prophet_hcltech = hcltech_reset[['Date','Adj Close']]
prophet_hcltech

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
prophet_hcltech.rename(columns={'Adj Close': 'y'}, inplace=True)
prophet_hcltech.rename(columns={'Date': 'ds'}, inplace=True)

# %%
# Split the data into train and test sets
prophet_train_size_hcltech = int(len(prophet_hcltech) * 0.8)
prophet_train_hcltech, prophet_test_hcltech = prophet_hcltech[:prophet_train_size_hcltech], prophet_hcltech[prophet_train_size_hcltech:]

# %%
# Create a Prophet model
prophet_model_hcltech = Prophet()

# Fit the model to your data
prophet_model_hcltech.fit(prophet_train_hcltech)

# %%
# Make predictions on the test set
prophet_future_hcltech = prophet_model_hcltech.make_future_dataframe(periods=len(prophet_test_hcltech))
prophet_forecast_hcltech = prophet_model_hcltech.predict(prophet_future_hcltech)

# %%
# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
y_true_hcltech = prophet_test_hcltech['y'].values
y_pred_hcltech = prophet_forecast_hcltech.loc[prophet_train_size_hcltech:, 'yhat'].values
prophet_mse_hcltech = mean_squared_error(y_true_hcltech, y_pred_hcltech)
prophet_rmse_hcltech = sqrt(prophet_mse_hcltech)

print(f'Mean Squared Error (MSE): {prophet_mse_hcltech:.2f}')
print(f'Root Mean Squared Error (RMSE): {prophet_rmse_hcltech:.2f}')

# %%
# Plotting train, test actual, and test predicted values with confidence intervals
fig, ax = plt.subplots(figsize=(12, 6))

# Plot training data
ax.plot(prophet_train_hcltech['ds'], prophet_train_hcltech['y'], label='Train', color='blue')

# Plot test data
ax.plot(prophet_test_hcltech['ds'], prophet_test_hcltech['y'], label='Test', color='green')

# Plot predicted values and uncertainty for the test data
ax.plot(prophet_test_hcltech['ds'], prophet_forecast_hcltech.loc[prophet_train_size_hcltech:, 'yhat'], label='Predicted', color='red')
ax.fill_between(prophet_test_hcltech['ds'], prophet_forecast_hcltech.loc[prophet_train_size_hcltech:, 'yhat_lower'], prophet_forecast_hcltech.loc[prophet_train_size_hcltech:, 'yhat_upper'], color='pink', alpha=0.5, label='Confidence Interval')

# Set labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('Adj Close Price')
ax.set_title('Prophet Model for HCL Technologies Ltd. Stock Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### HDFCBANK

# %%
# Reseting the Index
hdfcbank_reset = hdfcbank.reset_index()
hdfcbank_reset

# %%
prophet_hdfcbank = hdfcbank_reset[['Date','Adj Close']]
prophet_hdfcbank

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
prophet_hdfcbank.rename(columns={'Adj Close': 'y'}, inplace=True)
prophet_hdfcbank.rename(columns={'Date': 'ds'}, inplace=True)

# %%
# Split the data into train and test sets
prophet_train_size_hdfcbank = int(len(prophet_hdfcbank) * 0.8)
prophet_train_hdfcbank, prophet_test_hdfcbank = prophet_hdfcbank[:prophet_train_size_hdfcbank], prophet_hdfcbank[prophet_train_size_hdfcbank:]

# %%
# Create a Prophet model
prophet_model_hdfcbank = Prophet()

# Fit the model to your data
prophet_model_hdfcbank.fit(prophet_train_hdfcbank)

# %%
# Make predictions on the test set
prophet_future_hdfcbank = prophet_model_hdfcbank.make_future_dataframe(periods=len(prophet_test_hdfcbank))
prophet_forecast_hdfcbank = prophet_model_hdfcbank.predict(prophet_future_hdfcbank)

# %%
# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
y_true_hdfcbank = prophet_test_hdfcbank['y'].values
y_pred_hdfcbank = prophet_forecast_hdfcbank.loc[prophet_train_size_hdfcbank:, 'yhat'].values
prophet_mse_hdfcbank = mean_squared_error(y_true_hdfcbank, y_pred_hdfcbank)
prophet_rmse_hdfcbank = sqrt(prophet_mse_hdfcbank)

print(f'Mean Squared Error (MSE): {prophet_mse_hdfcbank:.2f}')
print(f'Root Mean Squared Error (RMSE): {prophet_rmse_hdfcbank:.2f}')

# %%
# Plotting train, test actual, and test predicted values with confidence intervals
fig, ax = plt.subplots(figsize=(12, 6))

# Plot training data
ax.plot(prophet_train_hdfcbank['ds'], prophet_train_hdfcbank['y'], label='Train', color='blue')

# Plot test data
ax.plot(prophet_test_hdfcbank['ds'], prophet_test_hdfcbank['y'], label='Test', color='green')

# Plot predicted values and uncertainty for the test data
ax.plot(prophet_test_hdfcbank['ds'], prophet_forecast_hdfcbank.loc[prophet_train_size_hdfcbank:, 'yhat'], label='Predicted', color='red')
ax.fill_between(prophet_test_hdfcbank['ds'], prophet_forecast_hdfcbank.loc[prophet_train_size_hdfcbank:, 'yhat_lower'], prophet_forecast_hdfcbank.loc[prophet_train_size_hdfcbank:, 'yhat_upper'], color='pink', alpha=0.5, label='Confidence Interval')

# Set labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('Adj Close Price')
ax.set_title('Prophet Model for HDFC Bank Ltd. Stock Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### DLF

# %%
dlf_reset = dlf.reset_index()
dlf_reset

# %%
prophet_dlf = dlf_reset[['Date','Adj Close']]
prophet_dlf

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
prophet_dlf.rename(columns={'Adj Close': 'y'}, inplace=True)
prophet_dlf.rename(columns={'Date': 'ds'}, inplace=True)

# %%
# Split the data into train and test sets
prophet_train_size_dlf = int(len(prophet_dlf) * 0.8)
prophet_train_dlf, prophet_test_dlf = prophet_dlf[:prophet_train_size_dlf], prophet_dlf[prophet_train_size_dlf:]

# %%
# Create a Prophet model
prophet_model_dlf = Prophet()

# Fit the model to your data
prophet_model_dlf.fit(prophet_train_dlf)

# %%
# Make predictions on the test set
prophet_future_dlf = prophet_model_dlf.make_future_dataframe(periods=len(prophet_test_dlf))
prophet_forecast_dlf = prophet_model_dlf.predict(prophet_future_dlf)

# %%
# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
y_true_dlf = prophet_test_dlf['y'].values
y_pred_dlf = prophet_forecast_dlf.loc[prophet_train_size_dlf:, 'yhat'].values
prophet_mse_dlf = mean_squared_error(y_true_dlf, y_pred_dlf)
prophet_rmse_dlf = sqrt(prophet_mse_dlf)

print(f'Mean Squared Error (MSE): {prophet_mse_dlf:.2f}')
print(f'Root Mean Squared Error (RMSE): {prophet_rmse_dlf:.2f}')

# %%
# Plotting train, test actual, and test predicted values with confidence intervals
fig, ax = plt.subplots(figsize=(12, 6))

# Plot training data
ax.plot(prophet_train_dlf['ds'], prophet_train_dlf['y'], label='Train', color='blue')

# Plot test data
ax.plot(prophet_test_dlf['ds'], prophet_test_dlf['y'], label='Test', color='green')

# Plot predicted values and uncertainty for the test data
ax.plot(prophet_test_dlf['ds'], prophet_forecast_dlf.loc[prophet_train_size_dlf:, 'yhat'], label='Predicted', color='red')
ax.fill_between(prophet_test_dlf['ds'], prophet_forecast_dlf.loc[prophet_train_size_dlf:, 'yhat_lower'], prophet_forecast_dlf.loc[prophet_train_size_dlf:, 'yhat_upper'], color='pink', alpha=0.5, label='Confidence Interval')

# Set labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('Adj Close Price')
ax.set_title('Prophet Model for DLF Ltd. Stock Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### NIFTY50

# %%
nifty50_reset = nifty50.reset_index()
nifty50_reset

# %%
prophet_nifty50 = nifty50_reset[['Date','Adj Close']].dropna()
prophet_nifty50

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
prophet_nifty50.rename(columns={'Adj Close': 'y'}, inplace=True)
prophet_nifty50.rename(columns={'Date': 'ds'}, inplace=True)

# %%
# Split the data into train and test sets
prophet_train_size_nifty50 = int(len(prophet_nifty50) * 0.8)
prophet_train_nifty50, prophet_test_nifty50 = prophet_nifty50[:prophet_train_size_nifty50], prophet_nifty50[prophet_train_size_nifty50:]

# %%
# Create a Prophet model
prophet_model_nifty50 = Prophet()

# Fit the model to your data
prophet_model_nifty50.fit(prophet_train_nifty50)

# %%
# Make predictions on the test set
prophet_future_nifty50 = prophet_model_nifty50.make_future_dataframe(periods=len(prophet_test_nifty50))
prophet_forecast_nifty50 = prophet_model_nifty50.predict(prophet_future_nifty50)

# %%
# Calculate Mean Squared Error (MSE) and Root Mean Squared Error (RMSE)
y_true_nifty50 = prophet_test_nifty50['y'].values
y_pred_nifty50 = prophet_forecast_nifty50.loc[prophet_train_size_nifty50:, 'yhat'].values
prophet_mse_nifty50 = mean_squared_error(y_true_nifty50, y_pred_nifty50)
prophet_rmse_nifty50 = sqrt(prophet_mse_nifty50)

print(f'Mean Squared Error (MSE): {prophet_mse_nifty50:.2f}')
print(f'Root Mean Squared Error (RMSE): {prophet_rmse_nifty50:.2f}')

# %%
# Plotting train, test actual, and test predicted values with confidence intervals
fig, ax = plt.subplots(figsize=(12, 6))

# Plot training data
ax.plot(prophet_train_nifty50['ds'], prophet_train_nifty50['y'], label='Train', color='blue')

# Plot test data
ax.plot(prophet_test_nifty50['ds'], prophet_test_nifty50['y'], label='Test', color='green')

# Plot predicted values and uncertainty for the test data
ax.plot(prophet_test_nifty50['ds'], prophet_forecast_nifty50.loc[prophet_train_size_nifty50:, 'yhat'], label='Predicted', color='red')
ax.fill_between(prophet_test_nifty50['ds'], prophet_forecast_nifty50.loc[prophet_train_size_nifty50:, 'yhat_lower'], prophet_forecast_nifty50.loc[prophet_train_size_nifty50:, 'yhat_upper'], color='pink', alpha=0.5, label='Confidence Interval')

# Set labels and legend
ax.set_xlabel('Date')
ax.set_ylabel('Adj Close Price')
ax.set_title('Prophet Model for NIFTY50 Stock Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### MSE & RMSE Values of each Stock of Both Models:
# **ARIMA Model**
#
# * SUNPHARMA - MSE: 7326.69 & RMSE: 85.60
#
# *** HCLTECH - MSE: 42192.49 & RMSE: 205.41**
#
# * HDFCBANK - MSE: 60805.99 & RMSE: 246.59
#
# * DLF - MSE: 2509.22 & RMSE: 50.09
#
# * NIFTY50 - MSE: 2984301.82 & RMSE: 1727.51
#
#
# **PROPHET Model**
#
# *** SUNPHARMA - MSE: 3380.16 & RMSE: 58.14**
#
# * HCLTECH - MSE: 56299.78 & RMSE: 237.28
#
# *** HDFCBANK - MSE: 12173.53 & RMSE: 110.33**
#
# *** DLF - MSE: 1964.81 & RMSE: 44.33**
#
# *** NIFTY50 - MSE: 1615480.36 & RMSE: 1271.02**

# %% [markdown]
# **From the above it can be seen that based on the RMSE values, out of ARIMA model & PROPHET model, ARIMA is appropriate for HCLTECH stock prediction and PROPHET is appropriate for the rest of the companies and index**

# %% [markdown]
# ## Future 'Adj Close' Value Prediction

# %% [markdown]
# **Now, we will predict the 'Adj Close' values for a 4-month tenure, from 01/04/2023 to 31/08/2023, for all stocks using the above models**

# %% [markdown]
# ### SUNPHARMA - PROPHET Model

# %%
# Make predictions for the future 5 months (April 2023 - August 2023)
future_dates = pd.date_range(start='2023-04-01', end='2023-08-31', freq='D')
future_df_sunpharma = pd.DataFrame({'ds': future_dates})
forecast_sunpharma = prophet_model_sunpharma.predict(future_df_sunpharma)

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
forecast_sunpharma.rename(columns={'yhat': 'Adj Close'}, inplace=True)
forecast_sunpharma.rename(columns={'ds': 'Date'}, inplace=True)

# %%
# Print the predicted Adj Close values
print(forecast_sunpharma[['Date','Adj Close']])

# %%
# Export the predictions CSV file
forecast_sunpharma.to_csv('sunpharma_pred.csv', index=False)

# %% [markdown]
# ### HCLTECH - ARIMA Model

# %%
# Define the date range for prediction
fut_start = datetime.strptime('31/03/2023 00:00:00', '%d/%m/%Y %H:%M:%S')
fut_end = datetime.strptime('31/08/2023 00:00:00', '%d/%m/%Y %H:%M:%S')

# %%
# Forecast future values
forecast_steps = len(pd.date_range(start=fut_start, end=fut_end))
forecast_hcltech = model_hcltech.get_forecast(steps=forecast_steps)

# Extract forecasted values and corresponding dates
forecast_values_hcltech = forecast_hcltech.predicted_mean
forecast_dates = pd.date_range(start=fut_start, periods=forecast_steps, freq='D')

# Create a DataFrame for the forecasted values
forecast_hcltech = pd.DataFrame({'Date': forecast_dates, 'Adj Close Forecast': forecast_values_hcltech})

# Print the forecasted values
print(forecast_hcltech)

# %%
test_hcltech.tail()

# %%
# Initialize a new column for the integrated predictions
forecast_hcltech['Integrated_Predictions'] = None

# Initialize the first value in the integrated predictions column with the initial value
forecast_hcltech.at[990, 'Integrated_Predictions'] = 1057.887573

# %%
len(forecast_hcltech)

# %%
# Loop through the DataFrame to perform the integration
for i in range(991, 1144):
    diff_fut_hcltech = forecast_hcltech.at[i, 'Adj Close Forecast']
    integrated_fut_hcltech = forecast_hcltech.at[i - 1, 'Integrated_Predictions'] + diff_fut_hcltech
    forecast_hcltech.at[i, 'Integrated_Predictions'] = integrated_fut_hcltech

# %%
# Printing the predictions
print(forecast_hcltech)

# %%
# Export the predictions CSV file
forecast_hcltech.to_csv('hcltech_pred.csv', index=True)

# %% [markdown]
# ### HDFCBANK - PROPHET Model

# %%
# Make predictions for the future 5 months (April 2023 - August 2023)
future_dates = pd.date_range(start='2023-04-01', end='2023-08-31', freq='D')
future_df_hdfcbank = pd.DataFrame({'ds': future_dates})
forecast_hdfcbank = prophet_model_hdfcbank.predict(future_df_hdfcbank)

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
forecast_hdfcbank.rename(columns={'yhat': 'Adj Close'}, inplace=True)
forecast_hdfcbank.rename(columns={'ds': 'Date'}, inplace=True)

# %%
# Print the predicted Adj Close values
print(forecast_hdfcbank[['Date','Adj Close']])

# %%
# Export the predictions CSV file
forecast_hdfcbank.to_csv('hdfcbank_pred.csv', index=True)

# %% [markdown]
# ### DLF - PROPHET Model

# %%
# Make predictions for the future 5 months (April 2023 - August 2023)
future_dates = pd.date_range(start='2023-04-01', end='2023-08-31', freq='D')
future_df_dlf = pd.DataFrame({'ds': future_dates})
forecast_dlf = prophet_model_dlf.predict(future_df_dlf)

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
forecast_dlf.rename(columns={'yhat': 'Adj Close'}, inplace=True)
forecast_dlf.rename(columns={'ds': 'Date'}, inplace=True)

# %%
# Print the predicted Adj Close values
print(forecast_dlf[['Date','Adj Close']])

# %%
# Export the predictions CSV file
forecast_dlf.to_csv('dlf_pred.csv', index=True)

# %% [markdown]
# ### NIFTY50 - PROPHET Model

# %%
# Make predictions for the future 5 months (April 2023 - August 2023)
future_dates = pd.date_range(start='2023-04-01', end='2023-08-31', freq='D')
future_df_nifty50 = pd.DataFrame({'ds': future_dates})
forecast_nifty50 = prophet_model_nifty50.predict(future_df_nifty50)

# %%
# Rename 'Adj Close' column to 'y' and 'Date' column to 'ds'
forecast_nifty50.rename(columns={'yhat': 'Adj Close'}, inplace=True)
forecast_nifty50.rename(columns={'ds': 'Date'}, inplace=True)

# %%
# Print the predicted Adj Close values
print(forecast_nifty50[['Date','Adj Close']])

# %%
# Export the predictions CSV file
forecast_nifty50.to_csv('nifty50_pred.csv', index=True)
